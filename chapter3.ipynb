# %% [markdown]
# ## 第三章 加工原始语料

# %%
from __future__ import division  # Python 2 users only
import re, pprint,nltk
from nltk import word_tokenize
from urllib import request
#from nltk import word_tokenize#在词上面的正则表达式

# %% [markdown]
# ## 从网络和磁盘访问文本

# %% [markdown]
# 访问网上电子书

# %%
url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
# Out:
# str

# %% [markdown]
# 将词分为标点符号和词语

# %%
test = 'My name is A. My name is B.'

# %%
word_tokenize(test)
# Out:
# ['My', 'name', 'is', 'A', '.', 'My', 'name', 'is', 'B', '.']

# %% [markdown]
# 从列表创建nltk text

# %%
text=nltk.Text(test)
type(text)
# Out:
# nltk.text.Text

# %%
tokens = word_tokenize(raw)

# %%
text.collocations?

# %% [markdown]
# ### 处理HTML文本

# %%
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
html = request.urlopen(url).read().decode('utf8')
html[:60]
# Out:
# '<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN'

# %% [markdown]
# 从html中提取文本，并对文本分词

# %%
from bs4 import BeautifulSoup
raw = BeautifulSoup(html, "html5lib").get_text()#取文本
tokens = word_tokenize(raw)
tokens
# Out:
# ['BBC',
#  'NEWS',
#  '|',
#  'Health',
#  '|',
#  'Blondes',
#  "'to",
#  'die',
#  'out',
#  'in',
#  '200',
#  "years'",
#  'NEWS',
#  'SPORT',
#  'WEATHER',
#  'WORLD',
#  'SERVICE',
#  'A-Z',
#  'INDEX',
#  'SEARCH',
#  'You',
#  'are',
#  'in',
#  ':',
#  'Health',
#  'News',
#  'Front',
#  'Page',
#  'Africa',
#  'Americas',
#  'Asia-Pacific',
#  'Europe',
#  'Middle',
#  'East',
#  'South',
#  'Asia',
#  'UK',
#  'Business',
#  'Entertainment',
#  'Science/Nature',
#  'Technology',
#  'Health',
#  'Medical',
#  'notes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Talking',
#  'Point',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Country',
#  'Profiles',
#  'In',
#  'Depth',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'Programmes',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  'SERVICES',
#  'Daily',
#  'E-mail',
#  'News',
#  'Ticker',
#  'Mobile/PDAs',
#  '--',
#  '--',
#  '--',
#  '--',
# ...

# %%
raw
# Out:
# '\nBBC NEWS | Health | Blondes \'to die out in 200 years\'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\t\t\n\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNEWS\n\xa0\xa0SPORT\n\xa0\xa0WEATHER\n\xa0\xa0WORLD SERVICE\n\n\xa0\xa0A-Z INDEX\xa0\n\n\xa0\xa0SEARCH\xa0\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n    \xa0You are in:\xa0Health \xa0\n    \n    \n\n\n\n\n\n    \n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\tNews Front Page\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\n\n\t\n\n\t\n\t\t\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\tAfrica\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\n\n\t\n\n\t\n\t\t\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\tAmericas\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\t\n\t\t\n\t\n\n\t\n\n\t\n\t\t\n\t\t\n\t\t\
# ...

# %%
tokens = tokens[110:390]
text = nltk.Text(tokens)
text.concordance('gene')#取出gene匹配上下文
# Out:
# Displaying 5 of 5 matches:
# hey say too few people now carry the gene for blondes to last beyond the next
# blonde hair is caused by a recessive gene . In order for a child to have blond
#  have blonde hair , it must have the gene on both sides of the family in the g
# ere is a disadvantage of having that gene or by chance . They do n't disappear
# des would disappear is if having the gene was a disadvantage and I do not thin

# %% [markdown]
# ### 处理RSS消息源（Feed）

# %%
import feedparser
llog = feedparser.parse("http://languagelog.ldc.upenn.edu/nll/?feed=atom")
llog['feed']['title']
# Out:
# 'Language Log'

# %% [markdown]
# 取得帖子的标题、内容等

# %% [markdown]
# ### 访问本地文件

# %%
f = open('release-texlive.txt')
f.read()
# Out:
# "TeX Live (http://tug.org/texlive) version 2016\\n\\nThis file is public domain.  It is read by install-tl --version,\\ntlmgr --version, and texconfig conf, and a final line appended with\\nthe precise version number by tl-update-images during a build.\\n\\nThe following blank line helps avoid confusing output when\\nused directly from svn, so don't delete it."

# %% [markdown]
# 每次读入一行

# %%
f = open('release-texlive.txt', 'r')
for line in f:
     print(line.strip())#去掉开头结尾的空白字符
# Out:
# TeX Live (http://tug.org/texlive) version 2016\n\nThis file is public domain.  It is read by install-tl --version,\ntlmgr --version, and texconfig conf, and a final line appended with\nthe precise version number by tl-update-images during a build.\n\nThe following blank line helps avoid confusing output when\nused directly from svn, so don't delete it.

# %% [markdown]
# ## 字符串的基本操作

# %% [markdown]
# 单引号或双引号来指定字符串

# %% [markdown]
# 跨行字符串：1）三引号,可以保留字符串内部的结构2）每行用双引号

# %% [markdown]
# #### print函数打印字符串

# %%
str1='my'
str2='name'
print(str1,str2)
# Out:
# my name

# %%
print(str1+str2)
# Out:
# myname

# %% [markdown]
# 负下标从后往前读 如str[-1]；反向索引[-12:-7]

# %%
str2[-2]
# Out:
# 'm'

# %% [markdown]
# ### 字符统计

# %%
from nltk.corpus import gutenberg
raw = gutenberg.raw('melville-moby_dick.txt')
fdist = nltk.FreqDist(ch.lower() for ch in raw if ch.isalpha())
fdist.most_common(5)#最常用的5个字符
# Out:
# [('e', 117092), ('t', 87996), ('a', 77916), ('o', 69326), ('n', 65617)]

# %%
[char[0] for char in fdist.most_common()]
# = [char for (char, count) in fdist.most_common()]
# Out:
# ['e',
#  't',
#  'a',
#  'o',
#  'n',
#  'i',
#  's',
#  'h',
#  'r',
#  'l',
#  'd',
#  'u',
#  'm',
#  'c',
#  'w',
#  'f',
#  'g',
#  'p',
#  'b',
#  'y',
#  'v',
#  'k',
#  'q',
#  'j',
#  'x',
#  'z']

# %% [markdown]
# ### 查找子字符串

# %% [markdown]
# 1）in 2）find函数; 自动机，后缀数；哈希

# %% [markdown]
# ## 使用unicode进行文字处理

# %% [markdown]
# 从文件中提取已编码文本

# %%
path = nltk.data.find('corpora/unicode_samples/polish-lat2.txt')

# %%
f = open(path,encoding='latin2')
for line in f:
    line = line.strip()
    print(line)
# Out:
# Pruska Biblioteka Państwowa. Jej dawne zbiory znane pod nazwą
# "Berlinka" to skarb kultury i sztuki niemieckiej. Przewiezione przez
# Niemców pod koniec II wojny światowej na Dolny Śląsk, zostały
# odnalezione po 1945 r. na terytorium Polski. Trafiły do Biblioteki
# Jagiellońskiej w Krakowie, obejmują ponad 500 tys. zabytkowych
# archiwaliów, m.in. manuskrypty Goethego, Mozarta, Beethovena, Bacha.

# %% [markdown]
# unicode_escape把所有非ASCII 字符转换成\uXXXX 形式

# %%
f = open(path, encoding='latin2')
for line in f:
    line = line.strip()
    print(line.encode('unicode_escape'))
# Out:
# b'Pruska Biblioteka Pa\\u0144stwowa. Jej dawne zbiory znane pod nazw\\u0105'
# b'"Berlinka" to skarb kultury i sztuki niemieckiej. Przewiezione przez'
# b'Niemc\\xf3w pod koniec II wojny \\u015bwiatowej na Dolny \\u015al\\u0105sk, zosta\\u0142y'
# b'odnalezione po 1945 r. na terytorium Polski. Trafi\\u0142y do Biblioteki'
# b'Jagiello\\u0144skiej w Krakowie, obejmuj\\u0105 ponad 500 tys. zabytkowych'
# b'archiwali\\xf3w, m.in. manuskrypty Goethego, Mozarta, Beethovena, Bacha.'

# %% [markdown]
# ## 使用正则表达式检测词语模式

# %%
import re
wordlist = [w for w in nltk.corpus.words.words('en') if w.islower()]

# %% [markdown]
# ### 使用基本元字符

# %% [markdown]
# 函数re.search(p,s)检查字符串s中是否有模式p

# %% [markdown]
# 使用正则表达式“ed$”查找以ed结尾的词汇

# %%
[w for w in wordlist if re.search('ed$',w)]
# Out:
# ['abaissed',
#  'abandoned',
#  'abased',
#  'abashed',
#  'abatised',
#  'abed',
#  'aborted',
#  'abridged',
#  'abscessed',
#  'absconded',
#  'absorbed',
#  'abstracted',
#  'abstricted',
#  'accelerated',
#  'accepted',
#  'accidented',
#  'accoladed',
#  'accolated',
#  'accomplished',
#  'accosted',
#  'accredited',
#  'accursed',
#  'accused',
#  'accustomed',
#  'acetated',
#  'acheweed',
#  'aciculated',
#  'aciliated',
#  'acknowledged',
#  'acorned',
#  'acquainted',
#  'acquired',
#  'acquisited',
#  'acred',
#  'aculeated',
#  'addebted',
#  'added',
#  'addicted',
#  'addlebrained',
#  'addleheaded',
#  'addlepated',
#  'addorsed',
#  'adempted',
#  'adfected',
#  'adjoined',
#  'admired',
#  'admitted',
#  'adnexed',
#  'adopted',
#  'adossed',
#  'adreamed',
#  'adscripted',
#  'aduncated',
#  'advanced',
#  'advised',
#  'aeried',
#  'aethered',
#  'afeared',
#  'affected',
#  'affectioned',
#  'affined',
#  'afflicted',
#  'affricated',
#  'affrighted',
# ...

# %% [markdown]
# ## 元字符

# %% [markdown]
# 通配符“.”匹配任何字符， 通配符“?”表示前面的字符可
# 选， “^”匹配字符串的开始，“$”匹配字符串的结尾

# %%
[w for w in wordlist if re.search('^..j..t..$',w)]
# Out:
# ['abjectly',
#  'adjuster',
#  'dejected',
#  'dejectly',
#  'injector',
#  'majestic',
#  'objectee',
#  'objector',
#  'rejecter',
#  'rejector',
#  'unjilted',
#  'unjolted',
#  'unjustly']

# %% [markdown]
# 方括号[]：范围限制。其中的字符没有顺序

# %% [markdown]
# T9输入法。 有哪些词汇由序列4653产生？

# %%
[w for w in wordlist if re.search('^[ghi][mno][jlk][def]$',w)]
# Out:
# ['gold', 'golf', 'hold', 'hole']

# %% [markdown]
# ‘-’表示区间，如«^[g-o]+$»
#
# '^'单独使用表示开头，‘^’ 在方括号内的第一个字符位置时出现表示排除
#
# 例如： «[^aeiouAEIOU]»匹配除元音字母之外的所有字母

# %% [markdown]
# ### 闭包

# %% [markdown]
# “+”表示的是前面的项目的一个或多个实例
#
# “*” 表示前面的项目的零个或多个实例

# %%
chat_words = sorted(set(w for w in nltk.corpus.nps_chat.words()))
[w for w in chat_words if re.search('^o+h+$', w)]
# Out:
# ['oh', 'ohh', 'ohhh', 'ohhhh', 'ohhhhhh', 'ohhhhhhhhhhhhhhhh', 'ooh', 'oooh']

# %% [markdown]
# ‘\’表示其后面的字母不再有特殊的含义而是按字面匹配
#
# ‘{}’指定前面项目的重复次数
#
# ‘|’ 字符表示从其左边的内容和右边的内容中选择一个
#
# ‘()’表示操作符的范围，可以与管道（‘|’ ） 符号一起使用

# %% [markdown]
# #### 匹配小数

# %%
wsj = sorted(set(nltk.corpus.treebank.words()))#华尔街日报
[ w for w in wsj if re.search('^[0-9]+\.[0-9]+$', w)]
# Out:
# ['0.0085',
#  '0.05',
#  '0.1',
#  '0.16',
#  '0.2',
#  '0.25',
#  '0.28',
#  '0.3',
#  '0.4',
#  '0.5',
#  '0.50',
#  '0.54',
#  '0.56',
#  '0.60',
#  '0.7',
#  '0.82',
#  '0.84',
#  '0.9',
#  '0.95',
#  '0.99',
#  '1.01',
#  '1.1',
#  '1.125',
#  '1.14',
#  '1.1650',
#  '1.17',
#  '1.18',
#  '1.19',
#  '1.2',
#  '1.20',
#  '1.24',
#  '1.25',
#  '1.26',
#  '1.28',
#  '1.35',
#  '1.39',
#  '1.4',
#  '1.457',
#  '1.46',
#  '1.49',
#  '1.5',
#  '1.50',
#  '1.55',
#  '1.56',
#  '1.5755',
#  '1.5805',
#  '1.6',
#  '1.61',
#  '1.637',
#  '1.64',
#  '1.65',
#  '1.7',
#  '1.75',
#  '1.76',
#  '1.8',
#  '1.82',
#  '1.8415',
#  '1.85',
#  '1.8500',
#  '1.9',
#  '1.916',
#  '1.92',
#  '10.19',
#  '10.2',
#  '10.5',
#  '107.03',
#  '107.9',
#  '109.73',
#  '11.10',
#  '11.5',
#  '11.57',
#  '11.6',
#  '11.72',
#  '11.95',
#  '112.9',
#  '113.2',
#  '116.3',
#  '116.4',
#  '116.7',
#  '116.9',
#  '118.6',
#  '12.09',
#  '12.5',
#  '12.52',
#  '12.68',
#  '12.7',
#  '12.82',
#  '12.97',
# ...

# %% [markdown]
# #### 匹配货币

# %%
[w for w in wsj if re.search('^[A-Z]+\$$', w)]
# Out:
# ['C$', 'US$']

# %% [markdown]
# #### 匹配年份

# %%
[w for w in wsj if re.search('^[0-9]{4}$',w)]
# Out:
# ['1614',
#  '1637',
#  '1787',
#  '1901',
#  '1903',
#  '1917',
#  '1925',
#  '1929',
#  '1933',
#  '1934',
#  '1948',
#  '1953',
#  '1955',
#  '1956',
#  '1961',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1975',
#  '1976',
#  '1977',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2005',
#  '2009',
#  '2017',
#  '2019',
#  '2029',
#  '3057',
#  '8300']

# %% [markdown]
# #### 匹配单词

# %%
[w for w in wsj if re.search('^[a-z]{5,}-[a-z]{2,3}-[a-z]{,6}', w)]#第一个单词超过5个字母，第三个单词小于6个字母
# Out:
# ['black-and-white',
#  'bread-and-butter',
#  'father-in-law',
#  'machine-gun-toting',
#  'savings-and-loan',
#  'search-and-seizure',
#  'truth-in-lending']

# %%
[w for w in wsj if re.search('(ed|ing)$',w)] #|前后不要加空格
# Out:
# ['62%-owned',
#  'Absorbed',
#  'According',
#  'Adopting',
#  'Advanced',
#  'Advancing',
#  'Alfred',
#  'Allied',
#  'Annualized',
#  'Anything',
#  'Arbitrage-related',
#  'Arbitraging',
#  'Asked',
#  'Assuming',
#  'Atlanta-based',
#  'Baking',
#  'Banking',
#  'Beginning',
#  'Beijing',
#  'Being',
#  'Bermuda-based',
#  'Betting',
#  'Boeing',
#  'Broadcasting',
#  'Bucking',
#  'Buying',
#  'Calif.-based',
#  'Change-ringing',
#  'Citing',
#  'Concerned',
#  'Confronted',
#  'Conn.based',
#  'Consolidated',
#  'Continued',
#  'Continuing',
#  'Declining',
#  'Defending',
#  'Depending',
#  'Designated',
#  'Determining',
#  'Developed',
#  'Died',
#  'During',
#  'Encouraged',
#  'Encouraging',
#  'English-speaking',
#  'Estimated',
#  'Everything',
#  'Excluding',
#  'Exxon-owned',
#  'Faulding',
#  'Fed',
#  'Feeding',
#  'Filling',
#  'Filmed',
#  'Financing',
#  'Following',
#  'Founded',
#  'Fracturing',
#  'Francisco-based',
#  'Fred',
#  'Funded',
#  'Funding',
# ...

# %% [markdown]
# ### 提取字符块

# %%
#找出元音
word='ahskiosuulfljdshflb'
re.findall(r'[aeiou]',word)
# Out:
# ['a', 'i', 'o', 'u', 'u']

# %% [markdown]
# 找出文本中的两个或两个以上的元音序列，并确定它们的相对频率

# %%
r'\t'
# Out:
# '\\t'

# %%
fd= nltk.FreqDist(vs for word in wsj for vs in re.findall(r'[aeiou]{2,}', word))
                  #'r'是防止字符转义的 如果路径中出现'\t'的话 不加r的话\t就会被转义 而加了'r'之后'\t'就能保留原有的样子
fd.items()
# Out:
# dict_items([('ea', 476), ('oi', 65), ('ou', 329), ('io', 549), ('ee', 217), ('ie', 331), ('ui', 95), ('ua', 109), ('ai', 261), ('ue', 105), ('ia', 253), ('ei', 86), ('iai', 1), ('oo', 174), ('au', 106), ('eau', 10), ('oa', 59), ('oei', 1), ('oe', 15), ('eo', 39), ('uu', 1), ('eu', 18), ('iu', 14), ('aii', 1), ('aiia', 1), ('ae', 11), ('aa', 3), ('oui', 6), ('ieu', 3), ('ao', 6), ('iou', 27), ('uee', 4), ('eou', 5), ('aia', 1), ('uie', 3), ('iao', 1), ('eei', 2), ('uo', 8), ('uou', 5), ('eea', 1), ('ueui', 1), ('ioa', 1), ('ooi', 1)])

# %% [markdown]
# 忽略词内部的元音（首尾则保留）

# %%
regexp = r'^[AEIOUaeiou]+|[AEIOUaeiou]+$|[^AEIOUaeiou]'
def compress(word):
    pieces = re.findall(regexp, word)
    return ''.join(pieces)

udhr = nltk.corpus.udhr.words('English-Latin1')
print(nltk.tokenwrap(compress(w) for w in udhr[:75]))
# Out:
# Unvrsl Dclrtn of Hmn Rghts Prmble Whrs rcgntn of the inhrnt dgnty and
# of the eql and inlnble rghts of all mmbrs of the hmn fmly is the fndtn
# of frdm , jstce and pce in the wrld , Whrs dsrgrd and cntmpt fr hmn
# rghts hve rsltd in brbrs acts whch hve outrgd the cnscnce of mnknd ,
# and the advnt of a wrld in whch hmn bngs shll enjy frdm of spch and

# %%
print(compress(w) for w in udhr[:75])
# Out:
# <generator object <genexpr> at 0x00000120B69D0F10>

# %% [markdown]
# 例子：从罗托卡特语词汇中提取所有辅音-元音序列

# %%
rototas = nltk.corpus.toolbox.words('rotokas.dic')
cvs = [cv for w in rototas 
          for cv in re.findall(r'[ptksvr][aeiou]', w)]
cfd = nltk.ConditionalFreqDist(cvs)
cfd.tabulate()#制表
# Out:
#     a   e   i   o   u
# k 418 148  94 420 173
# p  83  31 105  34  51
# r 187  63  84  89  79
# s   0   0 100   2   1
# t  47   8   0 148  37
# v  93  27 105  48  49

# %% [markdown]
# ### 索引

# %%
cv_word_pairs = [(cv, w) for w in rototas
                 for cv in re.findall(r'[ptksvr][aeiou]', w)]
cv_index = nltk.Index(cv_word_pairs)
cv_index['su']
# Out:
# ['kasuari']

# %% [markdown]
# ### 查找词干

# %%
#去掉结尾的。。。。
def stem(word):
    for suffix in ['ing', 'ly', 'ed', 'ious', 'ies', 'ive', 'es', 's', 'ment']:
        if word.endswith(suffix):
            return word[:-len(suffix)]
        return word
raw = """DENNIS: Listen, strange women lying in ponds distributing swords
    is no basis for a system of government.  Supreme executive power derives from
    a mandate from the masses, not from some farcical aquatic ceremony."""
tokens = word_tokenize(raw)
[stem(t) for t in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'women',
#  'ly',
#  'in',
#  'ponds',
#  'distribut',
#  'swords',
#  'is',
#  'no',
#  'basis',
#  'for',
#  'a',
#  'system',
#  'of',
#  'government',
#  '.',
#  'Supreme',
#  'executive',
#  'power',
#  'derives',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'masses',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %% [markdown]
# ### 搜索已分词(tokenize)文本

# %% [markdown]
# 找出a * man的实例
#
# 尖括号用于标记标识符的边界，尖括号之间的所有空白都被忽略（只对NLTK 中的findall()方法有效）
#
# “<.*>”将匹配所有单个标识符，将它括在括号里，表示只匹配词

# %%
from nltk.corpus import gutenberg, nps_chat
moby = nltk.Text(gutenberg.words('melville-moby_dick.txt'))
moby.findall(r"<a> (<.*>) <man>")#只把匹配的括号里的内容当做list返回
# Out:
# monied; nervous; dangerous; white; white; white; pious; queer; good;
# mature; white; Cape; great; wise; wise; butterless; white; fiendish;
# pale; furious; better; certain; complete; dismasted; younger; brave;
# brave; brave; brave

# %%
import re

# %%
re.findall('a(\\d+)a', 'aaaa9aaa102aaa')
# Out:
# ['9', '102']

# %% [markdown]
# ### 发现上位词

# %%
from nltk.corpus import brown
hobbies_learned = nltk.Text(brown.words(categories=['hobbies', 'learned']))
hobbies_learned.findall(r"<\w*> <and> <other> <\w*s>")
# Out:
# speed and other activities; water and other liquids; tomb and other
# landmarks; Statues and other monuments; pearls and other jewels;
# charts and other items; roads and other features; figures and other
# objects; military and other areas; demands and other factors;
# abstracts and other compilations; iron and other metals

# %%
re.findall(r"\b\w*\b \band\b \bother\b \b\w*s\b", "sdsadas iron and other metals")#python的写法 \b匹配边界
# Out:
# ['iron and other metals']

# %% [markdown]
# ## 文本规范化

# %% [markdown]
# ### 词干提取

# %% [markdown]
# Nltk使用的内部stemmer： Porter / Lancaster/ Snowball

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords
    is no basis for a system of government.  Supreme executive power derives from
    a mandate from the masses, not from some farcical aquatic ceremony."""
tokens = word_tokenize(raw)#原始单词list
porter = nltk.PorterStemmer()#porter算法
lancaster = nltk.LancasterStemmer()
[porter.stem(t) for t in tokens]#取词干
# Out:
# ['denni',
#  ':',
#  'listen',
#  ',',
#  'strang',
#  'women',
#  'lie',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'is',
#  'no',
#  'basi',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'suprem',
#  'execut',
#  'power',
#  'deriv',
#  'from',
#  'a',
#  'mandat',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcic',
#  'aquat',
#  'ceremoni',
#  '.']

# %%
[lancaster.stem(t) for t in tokens]#另一种算法 Lancaster
# Out:
# ['den',
#  ':',
#  'list',
#  ',',
#  'strange',
#  'wom',
#  'lying',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'is',
#  'no',
#  'bas',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'suprem',
#  'execut',
#  'pow',
#  'der',
#  'from',
#  'a',
#  'mand',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'som',
#  'farc',
#  'aqu',
#  'ceremony',
#  '.']

# %% [markdown]
# ## 利用Porter Stemmer索引文本

# %%
class IndexedText(object):

    def __init__(self, stemmer, text):#构造函数
        self._text = text
        self._stemmer = stemmer
        self._index = nltk.Index((self._stem(word), i)
                                 for (i, word) in enumerate(text))

    def concordance(self, word, width=40):
        key = self._stem(word)
        wc = int(width/4)                # words of context
        for i in self._index[key]:
            lcontext = ' '.join(self._text[i-wc:i])
            rcontext = ' '.join(self._text[i:i+wc])
            ldisplay = '%*s'  % (width, lcontext[-width:])
            rdisplay = '%-*s' % (width, rcontext[:width])
            print(ldisplay, rdisplay)

    def _stem(self, word):
        return self._stemmer.stem(word).lower()

# %% [markdown]
# 找lie的上下文，可能有多种不同形式

# %%
porter = nltk.PorterStemmer()#先找出词干，通过词干搜索
grail = nltk.corpus.webtext.words('grail.txt')#获取文本
text = IndexedText(porter, grail)
text.concordance('lie')
# Out:
# r king ! DENNIS : Listen , strange women lying in ponds distributing swords is no
#  beat a very brave retreat . ROBIN : All lies ! MINSTREL : [ singing ] Bravest of
#        Nay . Nay . Come . Come . You may lie here . Oh , but you are wounded !
# doctors immediately ! No , no , please ! Lie down . [ clap clap ] PIGLET : Well
# ere is much danger , for beyond the cave lies the Gorge of Eternal Peril , which
#    you . Oh ... TIM : To the north there lies a cave -- the cave of Caerbannog --
# h it and lived ! Bones of full fifty men lie strewn about its lair . So , brave k
# not stop our fight ' til each one of you lies dead , and the Holy Grail returns t

# %% [markdown]
# ## 词形恢复

# %% [markdown]
# 删除词缀，回到原形(在词典中)

# %%
wnl = nltk.WordNetLemmatizer()
[wnl.lemmatize(t) for t in tokens]# 把（文中的词）按屈折变化形式（或异体形式）进行归类
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'woman',
#  'lying',
#  'in',
#  'pond',
#  'distributing',
#  'sword',
#  'is',
#  'no',
#  'basis',
#  'for',
#  'a',
#  'system',
#  'of',
#  'government',
#  '.',
#  'Supreme',
#  'executive',
#  'power',
#  'derives',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %% [markdown]
# \S Any non-whitespace character (equivalent to [^ \t\n\r\f\v])
#
# \w Any alphanumeric character (equivalent to [a-zA-Z0-9_])
#
# «\w+([-']\w+)*»允许连字符和撇号
#
# «[-.(]+»，使双连字符、省略号和左括号被单独分词
#
# «\S\w*» 尝试匹配后面跟着词中字符的任何非空白字符，如's
#
# 使用括号来指定连接的范围，但不想选择要输出的字符串，必须添加“?:”
#
# «’»匹配引号字符

# %%
re.findall("\w+(?:[-']\w+)*","skjhd?ajd?")
#不捕捉模式
#关闭圆括号的捕获能力，只是用它来做分组，当成一个组合——在左括号的后边加上?：
# Out:
# ['skjhd', 'ajd']

# %% [markdown]
# ## NLTK 分词器

# %%
text = 'That U.S.A. poster-print costs $12.40...'
pattern = r"""(?x)                   # set flag to allow verbose regexps 
              (?:[A-Z]\.)+           # abbreviations, e.g. U.S.A. 
              |\d+(?:\.\d+)?%?       # numbers, incl. currency and percentages 
              |\w+(?:[-']\w+)*       # words w/ optional internal hyphens/apostrophe 
              |\.\.\.                # ellipsis 
              |(?:[.,;"'?():-_`])    # special characters with meanings 
            """ 
nltk.regexp_tokenize(text, pattern)
# Out:
# ['That', 'U.S.A.', 'poster-print', 'costs', '12.40', '...']

# %% [markdown]
# ## 断句

# %%
import pprint
text = nltk.corpus.gutenberg.raw('chesterton-thursday.txt')
sents = nltk.sent_tokenize(text)
pprint.pprint(sents[79:89])#以较好的格式输出
# Out:
# ['"Nonsense!"',
#  'said Gregory, who was very rational when anyone else\nattempted paradox.',
#  '"Why do all the clerks and navvies in the\n'
#  'railway trains look so sad and tired, so very sad and tired?',
#  'I will\ntell you.',
#  'It is because they know that the train is going right.',
#  'It\n'
#  'is because they know that whatever place they have taken a ticket\n'
#  'for that place they will reach.',
#  'It is because after they have\n'
#  'passed Sloane Square they know that the next station must be\n'
#  'Victoria, and nothing but Victoria.',
#  'Oh, their wild rapture!',
#  'oh,\n'
#  'their eyes like stars and their souls again in Eden, if the next\n'
#  'station were unaccountably Baker Street!"',
#  '"It is you who are unpoetical," replied the poet Syme.']

# %% [markdown]
# ## 中文分词

# %% [markdown]
# 中文特点：词语之间没有间隔
#
# 分词问题建模：给每个字符标注一个布尔值来指示这个字符后面是否需要分开

# %%
#在1的地方分割
def segment(text, segs):
    words = []
    last = 0
    for i in range(len(segs)):
        if segs[i] == '1':
            words.append(text[last:i+1])
            last = i+1
    words.append(text[last:])
    return words
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"
seg1 = "0000000000000001000000000010000000000000000100000000000"
seg2 = "0100100100100001001001000010100100010010000100010010000"
segment(text, seg1)
# Out:
# ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']

# %% [markdown]
# 工具包：jieba，smallseg；
#
# 或者一次性用第三方工具包处理好

# %% [markdown]
# tire 和 hash算法；从候选集中保留若干个可能性最大的分词路径 beam

# %% [markdown]
# ### 从列表到字符串

# %%
silly = ['I','love','you']
' '.join(silly)
# Out:
# 'I love you'

# %% [markdown]
# ## 排列
#
# %s和%d是字符串和整数的占位符
#
# 指定宽度: ”%6s”产生一个宽度为6 的字符串，右对齐

# %%
'%-6s'%'dog' #左对齐
# Out:
# 'dog   '

# %%
width=6
'%-*s'%(width,'dog')# *s的写法 等价上面
# Out:
# 'dog   '

# %% [markdown]
# ## 数据制表

# %%
def tabulate(cfdist, words, categories):
    print('{:16}'.format('Category'), end=' ')                    # column headings
    for word in words:
        print('{:>6}'.format(word), end=' ')
    print()
    for category in categories:
        print('{:16}'.format(category), end=' ')                  # row heading
        for word in words:                                        # for each word
            print('{:6}'.format(cfdist[category][word]), end=' ') # print table cell
        print()                                                    # end the row
from nltk.corpus import brown
cfd = nltk.ConditionalFreqDist(
              (genre, word)
              for genre in brown.categories()
             for word in brown.words(categories=genre))
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['can', 'could', 'may', 'might', 'must', 'will']
tabulate(cfd, modals, genres)
# Out:
# Category            can  could    may  might   must   will
# news                 93     86     66     38     50    389
# religion             82     59     78     12     54     71
# hobbies             268     58    131     22     83    264
# science_fiction      16     49      4     12      8     16
# romance              74    193     11     51     45     43
# humor                16     30      8      8      9     13

# %% [markdown]
# 关于文件输出（略）

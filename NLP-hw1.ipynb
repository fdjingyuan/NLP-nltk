# %%
import nltk
from nltk.book import* 
text2.dispersion_plot(['Elinor','Marianne','Edward','Willoughby'])

# %%
sorted([w for w in set(text5) if w.startswith('b')])
# Out:
# ['b',
#  'b-day',
#  'b/c',
#  'b4',
#  'babay',
#  'babble',
#  'babblein',
#  'babe',
#  'babes',
#  'babi',
#  'babies',
#  'babiess',
#  'baby',
#  'babycakeses',
#  'bachelorette',
#  'back',
#  'backatchya',
#  'backfrontsidewaysandallaroundtheworld',
#  'backroom',
#  'backup',
#  'bacl',
#  'bad',
#  'bag',
#  'bagel',
#  'bagels',
#  'bahahahaa',
#  'bak',
#  'baked',
#  'balad',
#  'balance',
#  'balck',
#  'ball',
#  'ballin',
#  'balls',
#  'ban',
#  'band',
#  'bandito',
#  'bandsaw',
#  'banjoes',
#  'banned',
#  'baord',
#  'bar',
#  'barbie',
#  'bare',
#  'barely',
#  'bares',
#  'barfights',
#  'barks',
#  'barn',
#  'barrel',
#  'base',
#  'bases',
#  'basically',
#  'basket',
#  'battery',
#  'bay',
#  'bbbbbyyyyyyyeeeeeeeee',
#  'bbiam',
#  'bbl',
#  'bbs',
#  'bc',
#  'be',
#  'beach',
#  'beachhhh',
#  'beam',
#  'beams',
#  'beanbag',
#  'beans',
#  'bear',
#  'bears',
#  'beat',
#  'beaten',
#  'beatles',
#  'beats',
#  'beattles',
#  'beautiful',
# ...

# %%
FreqDist([w for w in set(text5) if len(w)==5 and w.isalpha()]).keys()
# Out:
# dict_keys(['feeds', 'combo', 'Maybe', 'hafta', 'nicer', 'space', 'games', 'worst', 'hates', 'stans', 'hairs', 'Paxil', 'truck', 'rough', 'Filth', 'leash', 'neysa', 'omggg', 'sigur', 'chops', 'yello', 'jumps', 'shape', 'drive', 'charm', 'bosom', 'seems', 'harsh', 'neked', 'speed', 'hopin', 'hmmmm', 'didnt', 'nakie', 'throw', 'sassy', 'SHOWS', 'notes', 'drawn', 'sleep', 'fruit', 'sorry', 'large', 'chatr', 'GOING', 'rider', 'offer', 'quiet', 'beach', 'CHIPS', 'brady', 'youuu', 'coffe', 'Space', 'geesh', 'proud', 'other', 'punch', 'kicks', 'nitty', 'shell', 'beams', 'illin', 'scare', 'slick', 'twice', 'spell', 'sales', 'baked', 'quick', 'claws', 'knees', 'sesky', 'class', 'Ridin', 'yummy', 'rocks', 'ooeer', 'bucks', 'moths', 'tummy', 'brain', 'couch', 'pours', 'about', 'youer', 'scuse', 'Stick', 'given', 'misty', 'Clock', 'grabs', 'caint', 'happy', 'music', 'gotaa', 'Nadda', 'sucka', 'Guess', 'sauce', 'whats', 'gonna', 'alone', 'humor', 'reads', 'honey', 'lingo', 'those', 'allow', 'lying
# ...

# %% [markdown]
# 写表达式找出text2 中所有符合下列条件的词。结果应该是词链表的形式：['word 1', 'word2', ...]。a. 以er 结尾；b. 包含字母m；c. 包含字母序列ph；d. 除了首字母外是全部小写字母的词（即titlecase）。

# %%
sorted(w for w in set(text2) if w.endswith('er') and 'm' in w and 'ph' in w and (w.istitle() or w.islower()))
# Out:
# []

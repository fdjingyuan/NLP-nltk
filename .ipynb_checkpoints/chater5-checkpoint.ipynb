# %% [markdown]
# # 第五章 词性（词类）和词性标注

# %%
# %matplotlib inline
import nltk
from nltk import word_tokenizeize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-123ec4ba8916> in <module>()
#       1 get_ipython().magic('matplotlib inline')
#       2 import nltk
# ----> 3 from nltk import word_tokenizeize
#
# ImportError: cannot import name 'word_tokenizeize'

# %% [markdown]
# ## 词性和词性标注

# %% [markdown]
# 使用词性标注器处理词的序列，为每个词附加一个词性标记

# %%
#无歧义的情况
text = word_tokenize("And now for something completely different")
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('for', 'IN'),
#  ('something', 'NN'),
#  ('completely', 'RB'),
#  ('different', 'JJ')]

# %%
#有歧义的情况
text = word_tokenize("They refuse to permit us to obtain the refuse permit")
nltk.pos_tag(text)
# Out:
# [('They', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('permit', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('obtain', 'VB'),
#  ('the', 'DT'),
#  ('refuse', 'NN'),
#  ('permit', 'NN')]

# %% [markdown]
# ### 词性标注器的作用

# %% [markdown]
# 表征词语的用法，为结构分析服务

# %%
text = nltk.Text(word.lower() for word in nltk.corpus.brown.words())
text.similar('woman')
#搜索woman找到名词，搜索bought 找到是动词；搜索over 会找到介词；搜索the 找到限定词
# Out:
# man time day year car moment world house family child country boy
# state job place way war girl work word

# %% [markdown]
# ## 表示已标注的标识符

# %% [markdown]
# 已标注的标识符使用由标识符和标记组成的元组来表示
#
# 可以使用函数str2tuple从表示已标注的标识符的标准字符串创建这样的元组

# %%
tagged_token = nltk.tag.str2tuple('fly/NN')
tagged_token
# Out:
# ('fly', 'NN')

# %%
tagged_token[0]
# Out:
# 'fly'

# %% [markdown]
# 从一个字符串构造一个已经标注标识符的链表

# %%
sent = "This/AT is/IN a/AT wonderful/JJ day/NN"
[nltk.tag.str2tuple(t) for t in sent.split()]
# Out:
# [('This', 'AT'), ('is', 'IN'), ('a', 'AT'), ('wonderful', 'JJ'), ('day', 'NN')]

# %% [markdown]
# ## 读取标注语料库

# %% [markdown]
# 布朗库和词性映射

# %%
nltk.corpus.brown.tagged_words?

# %%
nltk.corpus.brown.tagged_words()
# Out:
# [('The', 'AT'), ('Fulton', 'NP-TL'), ...]

# %%
print(nltk.corpus.nps_chat.tagged_words())
# Out:
# [('now', 'RB'), ('im', 'PRP'), ('left', 'VBD'), ...]

# %%
nltk.corpus.treebank.tagged_words()
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ...]

# %%
nltk.corpus.treebank.tagged_words(tagset='universal')
# Out:
# [('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ...]

# %% [markdown]
# ### 常见词性

# %%
from nltk.corpus import brown
brown_news_tagged = brown.tagged_words(categories = 'news',tagset='universal')
tag_fd = nltk.FreqDist(tag for (word,tag) in brown_news_tagged)
tag_fd.most_common()
# Out:
# [('NOUN', 30654),
#  ('VERB', 14399),
#  ('ADP', 12355),
#  ('.', 11928),
#  ('DET', 11389),
#  ('ADJ', 6706),
#  ('ADV', 3349),
#  ('CONJ', 2717),
#  ('PRON', 2535),
#  ('PRT', 2264),
#  ('NUM', 2166),
#  ('X', 92)]

# %%
tag_fd.plot(cumulative = True)
#画图

# %% [markdown]
# 经常出现在名词之前的词性

# %%
word_tag_pairs = nltk.bigrams(brown_news_tagged)#一对（一个词，一个标签）
noun_preceders = [a[1] for (a,b) in word_tag_pairs if b[1] == 'NOUN']
#word_tag_pairs
#brown_news_tagged = brown.tagged_words(categories = 'news',tagset='universal')
fdist = nltk.FreqDist(noun_preceders)
[tag for (tag,_) in fdist.most_common()]
# Out:
# ['NOUN',
#  'DET',
#  'ADJ',
#  'ADP',
#  '.',
#  'VERB',
#  'CONJ',
#  'NUM',
#  'ADV',
#  'PRT',
#  'PRON',
#  'X']

# %%
word_tag_pairs = nltk.bigrams(brown_news_tagged)
next(word_tag_pairs)
# Out:
# (('The', 'DET'), ('Fulton', 'NOUN'))

# %% [markdown]
# 新闻文本中最常见的动词

# %%
wsj = nltk.corpus.treebank.tagged_words(tagset='universal')
word_tag_fd = nltk.FreqDist(wsj)
[wt[0] for (wt, _) in word_tag_fd.most_common() if wt[1] == 'VERB']
# Out:
# ['is',
#  'said',
#  'was',
#  'are',
#  'be',
#  'has',
#  'have',
#  'will',
#  'says',
#  'would',
#  'were',
#  'had',
#  'been',
#  'could',
#  "'s",
#  'can',
#  'do',
#  'say',
#  'make',
#  'may',
#  'did',
#  'rose',
#  'made',
#  'does',
#  'expected',
#  'buy',
#  'take',
#  'get',
#  'might',
#  'sell',
#  'added',
#  'sold',
#  'help',
#  'including',
#  'should',
#  'reported',
#  'according',
#  'pay',
#  'compared',
#  'being',
#  'fell',
#  'began',
#  'based',
#  'used',
#  'closed',
#  "'re",
#  'want',
#  'see',
#  'took',
#  'yield',
#  'offered',
#  'set',
#  'priced',
#  'approved',
#  'come',
#  'noted',
#  'cut',
#  'ended',
#  'found',
#  'increased',
#  'become',
#  'think',
#  'named',
#  'go',
#  'trying',
#  'proposed',
#  'received',
#  'growing',
#  'declined',
#  'held',
#  'give',
#  'came',
#  'use',
#  'put',
#  'making',
#  'continue',
#  'raise',
#  'estimated',
#  'called',
#  'paid',
#  'designed',
#  'going',
#  'expects',
#  'seeking',
#  'must',
#  'plans',
#  'wo',
#  'increasing',
#  'saying',
#  'got',
#  'owns',
#  'trading',
#  'acquired',
#  'gained',
#  'fined',
#  'reached',
#  'holding',
#  'announced',
#  'filed',
#  'became',
#  'seek',
#  'included',
#  'using',
#  'led',
#  'decided',
#  'keep',
#  'disclosed',
#  'agreed',
#  'find',
#  'failed',
#  'run',
#  'taken',
#  'know',
#  'coming',
#  "'ve",
#  'completed',
#  'built',
#  'raised',
#  'traded',
#  'lost',
#  'continued',
#  'paying',
#  'include',
#  'believe',
#  'receive',
#  'posted',
#  'wants',
#  'scheduled',
#  'went',
#  'indicated',
#  'provide',
#  'helped',
#  'needed',
#  'goes',
#  'told',
#  'result',
#  'need',
#  'caused',
#  'continues',
#  'dropped',
#  'showed',
#  'ordered',
#  'changed',
#  'face',
#  'continuing',
#  'launched',
#  'gives',
#  'reduce',
#  "'m",
#  'lead',
#  'planned',
#  'wanted',
#  'following',
#  'remains',
#  'followed',
#  'remain',
#  'meet',
#  'believes',
#  'trade',
#  'includes',
#  'improve',
#  'buying',
#  'issued',
#  'rise',
#  'leading',
#  'ca',
#  'involved',
#  'known',
#  'like',
#  'makes',
#  'having',
#  'rejected',
#  'rising',
#  'increase',
#  'turned',
#  'operating',
#  'read',
#  'feel',
#  'win',
#  'given',
#  'prevent',
#  'offset',
#  'barred',
#  'earned',
#  'consented',
#  'support',
#  'gave',
#  'totaled',
#  'acquire',
#  'required',
#  'begin',
#  'require',
#  'offer',
#  'preferred',
#  'produced',
#  'bought',
#  'offering',
#  'asked',
#  'carry',
#  'build',
#  'takes',
#  'seem',
#  'introduced',
#  'taking',
#  'won',
#  'aimed',
#  'hurt',
#  'adds',
#  'cited',
#  'sought',
#  'bring',
#  'remaining',
#  'considered',
#  'suspended',
#  'prove',
#  'looking',
#  'doing',
#  'involving',
#  'opened',
#  'working',
#  'close',
#  'own',
#  'report',
#  'left',
#  'boosted',
#  'giving',
#  'fixed',
#  'listed',
#  'runs',
#  'purchasing',
#  'consider',
#  'prepared',
#  'hit',
#  'getting',
#  'alleged',
#  'look',
#  'allowed',
#  'approve',
#  'wrote',
#  'reduced',
#  'fall',
#  'advanced',
#  'appears',
#  'mixed',
#  'described',
#  'expect',
#  'manufacturing',
#  'spent',
#  'According',
#  'hopes',
#  'underlying',
#  'produce',
#  'work',
#  'placed',
#  'allow',
#  'sells',
#  'operate',
#  'extend',
#  'surged',
#  'jumped',
#  'boost',
#  'slowing',
#  'provided',
#  'seems',
#  'ending',
#  'selling',
#  'opposed',
#  'created',
#  'move',
#  'seen',
#  'comment',
#  'valued',
#  'losing',
#  'mature',
#  'provides',
#  'let',
#  'stopped',
#  'worked',
#  'thought',
#  'watch',
#  'introduce',
#  'related',
#  'improved',
#  'raising',
#  'seemed',
#  'force',
#  'beginning',
#  'leave',
#  'believed',
#  'stand',
#  'developed',
#  'decline',
#  'expire',
#  'managing',
#  'hold',
#  'invested',
#  'suggests',
#  'represent',
#  'settle',
#  'change',
#  'contributed',
#  'indicates',
#  'asking',
#  'elaborate',
#  'shows',
#  'refused',
#  'quoted',
#  'comes',
#  'ease',
#  'passed',
#  'Says',
#  'avoid',
#  'threatened',
#  'cause',
#  'end',
#  'violate',
#  'operates',
#  'kept',
#  "'ll",
#  'soared',
#  'eliminated',
#  'becomes',
#  'create',
#  'print',
#  'shall',
#  'show',
#  'replaced',
#  'owned',
#  'argue',
#  'beat',
#  'elected',
#  'complete',
#  'issue',
#  'act',
#  'return',
#  'registered',
#  'suffer',
#  'worried',
#  'succeed',
#  'block',
#  'contain',
#  'occur',
#  'pursue',
#  'combined',
#  'requires',
#  'met',
#  'brought',
#  'started',
#  'covered',
#  'turn',
#  'running',
#  'eliminate',
#  'file',
#  'plunged',
#  'fallen',
#  'ran',
#  'fired',
#  'becoming',
#  'contained',
#  'managed',
#  'Take',
#  'suggested',
#  'accused',
#  'appeared',
#  'slow',
#  'helping',
#  'discovered',
#  'add',
#  'referred',
#  'oppose',
#  'stop',
#  'claim',
#  'sent',
#  'formed',
#  'resulting',
#  'turning',
#  'limited',
#  'shipped',
#  'forced',
#  'send',
#  'attract',
#  'admitting',
#  'denying',
#  'disgorge',
#  'attributed',
#  'causing',
#  'studied',
#  'resigned',
#  'cutting',
#  'voted',
#  'settled',
#  'expand',
#  'stood',
#  'retired',
#  'moved',
#  'pending',
#  'providing',
#  'anticipated',
#  'decide',
#  'creating',
#  'prompted',
#  'developing',
#  'start',
#  'maintained',
#  'expanding',
#  'follows',
#  'ranged',
#  'focused',
#  'climbed',
#  'reflect',
#  'insist',
#  'owed',
#  'happen',
#  'adjusted',
#  'awarded',
#  'reporting',
#  'talk',
#  'offers',
#  'written',
#  'urged',
#  'carried',
#  'identified',
#  'confirmed',
#  'playing',
#  'thinking',
#  'calls',
#  'means',
#  'tried',
#  'lying',
#  'asks',
#  'building',
#  'suggest',
#  'falling',
#  'discuss',
#  'matched',
#  'concluded',
#  'keeping',
#  "'d",
#  'returned',
#  'withdrawn',
#  'bid',
#  'saw',
#  'signed',
#  'financing',
#  'assuming',
#  'adopted',
#  'attempting',
#  'accepted',
#  'cover',
#  'facing',
#  'risk',
#  'expanded',
#  'leaving',
#  'raises',
#  'declared',
#  'exercise',
#  'finished',
#  'regarding',
#  'finance',
#  'charge',
#  'starting',
#  'realize',
#  'felt',
#  'remained',
#  'expressed',
#  'done',
#  'replace',
#  'veto',
#  'stay',
#  'delivered',
#  'join',
#  'publishing',
#  'enters',
#  'appear',
#  'talking',
#  'heard',
#  'dumped',
#  'imported',
#  'assume',
#  'declining',
#  'capture',
#  'grew',
#  'holds',
#  'lift',
#  'treat',
#  'receiving',
#  'joined',
#  'reflecting',
#  'released',
#  'maintaining',
#  'cost',
#  'lowered',
#  'costs',
#  'exceed',
#  'gaining',
#  'considering',
#  'determined',
#  'ruled',
#  'hope',
#  'located',
#  'tied',
#  'heads',
#  'applied',
#  'failing',
#  'showing',
#  'apply',
#  'protecting',
#  'tells',
#  'complained',
#  'ask',
#  'triggered',
#  'entered',
#  'total',
#  'producing',
#  'denied',
#  'reducing',
#  'reflects',
#  'account',
#  'predicting',
#  'intended',
#  'purchased',
#  'blamed',
#  'worry',
#  'broken',
#  'carries',
#  'learned',
#  'renewed',
#  'walk',
#  'viewed',
#  'die',
#  'speculated',
#  'needs',
#  'gets',
#  'wait',
#  'caught',
#  'claims',
#  'choose',
#  'fail',
#  'insists',
#  'knows',
#  'pass',
#  'grown',
#  'gotten',
#  'grows',
#  'responded',
#  'play',
#  'try',
#  'mean',
#  'encourage',
#  'chosen',
#  'admits',
#  'Do',
#  'dismissed',
#  'realized',
#  'serve',
#  'associated',
#  'slipped',
#  'argued',
#  'citing',
#  'seeks',
#  'preventing',
#  'sparked',
#  'review',
#  'opening',
#  'fueled',
#  'negotiate',
#  'drop',
#  'pleased',
#  'spend',
#  'care',
#  'represents',
#  'spread',
#  'explains',
#  'push',
#  'divided',
#  'proposing',
#  'gain',
#  'representing',
#  'financed',
#  'execute',
#  'existing',
#  'discussed',
#  'uses',
#  'live',
#  'ring',
#  'signal',
#  'focus',
#  'hired',
#  'limit',
#  'begins',
#  'reflected',
#  'hear',
#  'determine',
#  'profit',
#  'marketed',
#  'warned',
#  'qualified',
#  'died',
#  'surviving',
#  'study',
#  'explained',
#  'imposed',
#  'recognize',
#  'eased',
#  'indicate',
#  'permit',
#  'retain',
#  'yielding',
#  'boosts',
#  'obtain',
#  'employs',
#  'banned',
#  'pointed',
#  'leaves',
#  'withdraw',
#  'refund',
#  'collected',
#  'upheld',
#  'benefited',
#  'doubled',
#  'attached',
#  'jump',
#  'compete',
#  'incurred',
#  'removed',
#  'honor',
#  'varying',
#  'marketing',
#  'protect',
#  'reach',
#  'share',
#  'requested',
#  'grant',
#  'stepping',
#  'direct',
#  'curb',
#  'controlling',
#  'snapped',
#  'tend',
#  'cast',
#  'clear',
#  'permitted',
#  'remove',
#  'revive',
#  'draw',
#  'predicted',
#  'suspect',
#  'coupled',
#  'belong',
#  'call',
#  'describes',
#  'played',
#  'committed',
#  'advertising',
#  'tested',
#  'revived',
#  'earns',
#  'feeling',
#  'turns',
#  'executed',
#  'killed',
#  'presented',
#  'deserve',
#  'mention',
#  'seeing',
#  'discussing',
#  'convicted',
#  'telling',
#  'agree',
#  'denies',
#  'pursued',
#  'spurred',
#  'accommodate',
#  'surrendered',
#  'gone',
#  'teach',
#  'booming',
#  'serving',
#  'restore',
#  'restructured',
#  'taught',
#  'feared',
#  'meant',
#  'adding',
#  'publishes',
#  'improving',
#  'ignoring',
#  'represented',
#  'funded',
#  'involve',
#  'charged',
#  'fared',
#  'eliminates',
#  'tumbled',
#  'redeemed',
#  'resolve',
#  'stem',
#  'hire',
#  'obtained',
#  'develop',
#  'employed',
#  'prohibits',
#  'promote',
#  'impose',
#  'consist',
#  'investigating',
#  'accepting',
#  'plan',
#  'insisted',
#  'contacted',
#  'note',
#  'driving',
#  'contends',
#  'cites',
#  'point',
#  'sign',
#  'printed',
#  'advertise',
#  'breaks',
#  'damaged',
#  'check',
#  'thinks',
#  'looming',
#  'expecting',
#  'exercised',
#  'auctioned',
#  'disappointed',
#  'subordinated',
#  'respond',
#  'secured',
#  'integrated',
#  'performed',
#  'targeting',
#  'stepped',
#  'moving',
#  'split',
#  'Buy',
#  'stemming',
#  'executing',
#  'shut',
#  'writing',
#  'regulated',
#  'stands',
#  'attend',
#  'reopen',
#  'drawn',
#  'Put',
#  'notes',
#  'weaken',
#  'trailed',
#  'deliver',
#  'occurred',
#  'changing',
#  'accept',
#  'expelled',
#  'amounted',
#  'scrutinizing',
#  'suspend',
#  'compares',
#  'backed',
#  'vote',
#  'covers',
#  'knew',
#  'joining',
#  'record',
#  'regarded',
#  'copy',
#  'conclude',
#  'ought',
#  'dominated',
#  'pushed',
#  'closing',
#  'rumored',
#  'respected',
#  'specified',
#  'understand',
#  'supported',
#  'perform',
#  'declaring',
#  'struggling',
#  'abandoned',
#  'considers',
#  'warning',
#  'offsetting',
#  'break',
#  'follow',
#  'figure',
#  'increases',
#  'proving',
#  'edged',
#  'Buying',
#  'forecast',
#  'specify',
#  'extended',
#  'tendered',
#  'unveiled',
#  'treating',
#  'exposed',
#  'industrialized',
#  'regulate',
#  'contracted',
#  'blip',
#  'vary',
#  'slid',
#  'succeeds',
#  'lifted',
#  'acts',
#  'welcomed',
#  'squeezed',
#  'fed',
#  'casting',
#  'prolonged',
#  'recorded',
#  'announce',
#  'reward',
#  'bowed',
#  'justify',
#  'asserted',
#  'appealing',
#  'faces',
#  'rule',
#  'inched',
#  'manufacture',
#  'fund',
#  'anticipates',
#  'link',
#  'describe',
#  'roll',
#  'calculate',
#  'transferring',
#  'favored',
#  'claiming',
#  'hurting',
#  'investing',
#  'trained',
#  'instituted',
#  'introducing',
#  'vowed',
#  'deemed',
#  'pose',
#  'concerned',
#  'accelerated',
#  'feels',
#  'solved',
#  'forgiven',
#  'stored',
#  'assembled',
#  'totaling',
#  'linked',
#  'forces',
#  'attempts',
#  'advertised',
#  'marks',
#  'sweeping',
#  'invest',
#  'kicked',
#  'brings',
#  'scrambled',
#  'diversify',
#  'swing',
#  'skyrocketed',
#  'targeted',
#  'repaid',
#  'open',
#  'crippled',
#  'lent',
#  'belongs',
#  'stressed',
#  'leveling',
#  'manufactured',
#  'pick',
#  'cite',
#  'provoke',
#  'last',
#  'climbing',
#  'Excluding',
#  'adjusting',
#  'counts',
#  'handle',
#  'polled',
#  'drink',
#  'sets',
#  'sidestep',
#  'fare',
#  'letting',
#  'entering',
#  'ban',
#  'visiting',
#  'endorsed',
#  'balked',
#  'compensate',
#  'terminated',
#  'modify',
#  'operated',
#  'entitles',
#  'romanticized',
#  'spends',
#  'condemned',
#  'competing',
#  'returning',
#  'murdered',
#  'load',
#  'lives',
#  'recommend',
#  'fighting',
#  'fills',
#  'charges',
#  'exist',
#  'Stung',
#  'banning',
#  'admitted',
#  'talks',
#  'launch',
#  'attracted',
#  'featured',
#  'devote',
#  'featuring',
#  'suing',
#  'shrinks',
#  'tripled',
#  'pumping',
#  'contributing',
#  'spur',
#  'concentrated',
#  'export',
#  'pull',
#  'approach',
#  'step',
#  'regard',
#  'breach',
#  'pleaded',
#  'inspired',
#  'defended',
#  'treated',
#  'casts',
#  'violated',
#  'enforce',
#  'surfaced',
#  'concentrate',
#  'stressing',
#  'suffered',
#  'loved',
#  'advised',
#  'studying',
#  'pushing',
#  'earn',
#  'save',
#  'interviewed',
#  'explain',
#  'gauge',
#  'measured',
#  'deny',
#  'hampered',
#  'fill',
#  'nominated',
#  'assured',
#  'finding',
#  'conducting',
#  'tracks',
#  'merge',
#  'merged',
#  'banking',
#  'achieve',
#  'acquiring',
#  'post',
#  'wish',
#  'retained',
#  'spark',
#  'chaired',
#  'deal',
#  'submit',
#  'sending',
#  'test',
#  'relegated',
#  'alleging',
#  'mounted',
#  'harass',
#  'crossing',
#  'involves',
#  'assist',
#  'killing',
#  'served',
#  'understood',
#  'touch',
#  'Asked',
#  'design',
#  'retaining',
#  'belonging',
#  'compiled',
#  'Guaranteed',
#  'positioned',
#  'plunging',
#  'locked',
#  'starts',
#  'waiting',
#  'rolled',
#  'lock',
#  'drifted',
#  'measures',
#  'Estimated',
#  ...]

# %%
word_tag_fd
# Out:
# FreqDist({('Pierre', 'NOUN'): 1,
#           ('Vinken', 'NOUN'): 2,
#           (',', '.'): 4885,
#           ('61', 'NUM'): 5,
#           ('years', 'NOUN'): 115,
#           ('old', 'ADJ'): 24,
#           ('will', 'VERB'): 280,
#           ('join', 'VERB'): 4,
#           ('the', 'DET'): 4038,
#           ('board', 'NOUN'): 30,
#           ('as', 'ADP'): 333,
#           ('a', 'DET'): 1874,
#           ('nonexecutive', 'ADJ'): 5,
#           ('director', 'NOUN'): 32,
#           ('Nov.', 'NOUN'): 24,
#           ('29', 'NUM'): 5,
#           ('.', '.'): 3828,
#           ('Mr.', 'NOUN'): 375,
#           ('is', 'VERB'): 671,
#           ('chairman', 'NOUN'): 45,
#           ('of', 'ADP'): 2319,
#           ('Elsevier', 'NOUN'): 1,
#           ('N.V.', 'NOUN'): 3,
#           ('Dutch', 'NOUN'): 1,
#           ('publishing', 'VERB'): 4,
#           ('group', 'NOUN'): 43,
#           ('Rudolph', 'NOUN'): 3,
#           ('Agnew', 'NOUN'): 1,
#           ('55', 'NUM'): 10,
#           ('and', 'CONJ'): 1505,
#           ('former', 'ADJ'): 19,
#           ('Consolidated', 'NOUN'): 2,
#           ('Gold', 'NOUN'): 2,
#           ('Fields', 'NOUN'): 2,
#           ('PLC', 'NOUN'): 13,
#           ('was', 'VERB'): 367,
#           ('named', 'VERB'): 22,
#           ('*-1', 'X'): 1123,
#           ('this', 'DET'): 184,
#           ('British', 'ADJ'): 7,
#           ('industrial', 'ADJ'): 18,
#           ('conglomerate', 'NOUN'): 3,
#           ('A', 'DET'): 105,
#           ('form', 'NOUN'): 16,
#           ('asbestos', 'NOUN'): 11,
#           ('once', 'ADV'): 13,
#           ('used', 'VERB'): 30,
#           ('*', 'X'): 965,
#           ('to', 'PRT'): 2161,
#           ('make', 'VERB'): 73,
#           ('Kent', 'NOUN'): 8,
#           ('cigarette', 'NOUN'): 4,
#           ('filters', 'NOUN'): 7,
#           ('has', 'VERB'): 339,
#           ('caused', 'VERB'): 13,
#           ('high', 'ADJ'): 26,
#           ('percentage', 'NOUN'): 11,
#           ('cancer', 'NOUN'): 7,
#           ('deaths', 'NOUN'): 6,
#           ('among', 'ADP'): 31,
#           ('workers', 'NOUN'): 20,
#           ('exposed', 'VERB'): 2,
#           ('it', 'PRON'): 476,
#           ('more', 'ADV'): 86,
#           ('than', 'ADP'): 180,
#           ('30', 'NUM'): 47,
#           ('ago', 'ADP'): 22,
#           ('researchers', 'NOUN'): 13,
#           ('reported', 'VERB'): 37,
#           ('0', 'X'): 1099,
#           ('*T*-1', 'X'): 806,
#           ('The', 'DET'): 713,
#           ('fiber', 'NOUN'): 1,
#           ('crocidolite', 'NOUN'): 5,
#           ('unusually', 'ADV'): 2,
#           ('resilient', 'ADJ'): 1,
#           ('once', 'ADP'): 1,
#           ('enters', 'VERB'): 4,
#           ('lungs', 'NOUN'): 1,
#           ('with', 'ADP'): 387,
#           ('even', 'ADV'): 64,
#           ('brief', 'ADJ'): 4,
#           ('exposures', 'NOUN'): 3,
#           ('causing', 'VERB'): 5,
#           ('symptoms', 'NOUN'): 1,
#           ('that', 'DET'): 291,
#           ('show', 'VERB'): 6,
#           ('up', 'PRT'): 77,
#           ('decades', 'NOUN'): 3,
#           ('later', 'ADJ'): 11,
#           ('said', 'VERB'): 628,
#           ('*T*-2', 'X'): 345,
#           ('Lorillard', 'NOUN'): 5,
#           ('Inc.', 'NOUN'): 97,
#           ('unit', 'NOUN'): 36,
#           ('New', 'ADJ'): 6,
#           ('York-based', 'ADJ'): 4,
#           ('Loews', 'NOUN'): 1,
#           ('Corp.', 'NOUN'): 117,
#           ('makes', 'VERB'): 11,
#           ('cigarettes', 'NOUN'): 6,
#           ('stopped', 'VERB'): 7,
#           ('using', 'VERB'): 16,
#           ('in', 'ADP'): 1554,
#           ('its', 'PRON'): 332,
#           ('Micronite', 'NOUN'): 1,
#           ('1956', 'NUM'): 2,
#           ('Although', 'ADP'): 14,
#           ('preliminary', 'ADJ'): 5,
#           ('findings', 'NOUN'): 8,
#           ('were', 'VERB'): 197,
#           ('*-2', 'X'): 372,
#           ('year', 'NOUN'): 212,
#           ('latest', 'ADJ'): 22,
#           ('results', 'NOUN'): 21,
#           ('appear', 'VERB'): 4,
#           ('today', 'NOUN'): 22,
#           ("'s", 'PRT'): 761,
#           ('New', 'NOUN'): 159,
#           ('England', 'NOUN'): 23,
#           ('Journal', 'NOUN'): 10,
#           ('Medicine', 'NOUN'): 5,
#           ('forum', 'NOUN'): 2,
#           ('likely', 'ADJ'): 20,
#           ('bring', 'VERB'): 9,
#           ('new', 'ADJ'): 162,
#           ('attention', 'NOUN'): 8,
#           ('problem', 'NOUN'): 30,
#           ('spokewoman', 'NOUN'): 1,
#           ('``', '.'): 702,
#           ('This', 'DET'): 40,
#           ('an', 'DET'): 316,
#           ('story', 'NOUN'): 6,
#           ('We', 'PRON'): 47,
#           ("'re", 'VERB'): 29,
#           ('talking', 'VERB'): 4,
#           ('about', 'ADP'): 176,
#           ('before', 'ADP'): 42,
#           ('anyone', 'NOUN'): 6,
#           ('heard', 'VERB'): 4,
#           ('having', 'VERB'): 11,
#           ('any', 'DET'): 103,
#           ('questionable', 'ADJ'): 3,
#           ('properties', 'NOUN'): 1,
#           ('There', 'DET'): 32,
#           ('no', 'DET'): 76,
#           ('our', 'PRON'): 26,
#           ('products', 'NOUN'): 32,
#           ('now', 'ADV'): 61,
#           ("''", '.'): 684,
#           ('Neither', 'DET'): 5,
#           ('nor', 'CONJ'): 11,
#           ('who', 'PRON'): 163,
#           ('*T*-3', 'X'): 97,
#           ('studied', 'VERB'): 5,
#           ('aware', 'ADJ'): 3,
#           ('research', 'NOUN'): 33,
#           ('on', 'ADP'): 483,
#           ('smokers', 'NOUN'): 2,
#           ('have', 'VERB'): 323,
#           ('useful', 'ADJ'): 2,
#           ('information', 'NOUN'): 26,
#           ('whether', 'ADP'): 28,
#           ('users', 'NOUN'): 2,
#           ('are', 'VERB'): 367,
#           ('at', 'ADP'): 402,
#           ('risk', 'NOUN'): 7,
#           ('James', 'NOUN'): 22,
#           ('A.', 'NOUN'): 18,
#           ('Talcott', 'NOUN'): 4,
#           ('Boston', 'NOUN'): 17,
#           ('Dana-Farber', 'NOUN'): 1,
#           ('Cancer', 'NOUN'): 2,
#           ('Institute', 'NOUN'): 15,
#           ('Dr.', 'NOUN'): 13,
#           ('led', 'VERB'): 16,
#           ('team', 'NOUN'): 17,
#           ('from', 'ADP'): 386,
#           ('National', 'NOUN'): 20,
#           ('medical', 'ADJ'): 7,
#           ('schools', 'NOUN'): 9,
#           ('Harvard', 'NOUN'): 3,
#           ('University', 'NOUN'): 22,
#           ('spokeswoman', 'NOUN'): 8,
#           ('very', 'ADV'): 28,
#           ('modest', 'ADJ'): 3,
#           ('amounts', 'NOUN'): 5,
#           ('making', 'VERB'): 20,
#           ('paper', 'NOUN'): 28,
#           ('for', 'ADP'): 815,
#           ('early', 'ADJ'): 29,
#           ('1950s', 'NUM'): 2,
#           ('replaced', 'VERB'): 6,
#           ('different', 'ADJ'): 21,
#           ('type', 'NOUN'): 11,
#           ('filter', 'NOUN'): 1,
#           ('From', 'ADP'): 5,
#           ('1953', 'NUM'): 1,
#           ('1955', 'NUM'): 1,
#           ('9.8', 'NUM'): 2,
#           ('billion', 'NUM'): 159,
#           ('sold', 'VERB'): 39,
#           ('*-3', 'X'): 130,
#           ('company', 'NOUN'): 260,
#           ('Among', 'ADP'): 13,
#           ('33', 'NUM'): 7,
#           ('men', 'NOUN'): 10,
#           ('*T*-4', 'X'): 23,
#           ('worked', 'VERB'): 7,
#           ('closely', 'ADV'): 15,
#           ('substance', 'NOUN'): 5,
#           ('28', 'NUM'): 4,
#           ('*ICH*-1', 'X'): 70,
#           ('died', 'VERB'): 3,
#           ('--', '.'): 230,
#           ('more', 'ADJ'): 112,
#           ('three', 'NUM'): 48,
#           ('times', 'NOUN'): 16,
#           ('expected', 'VERB'): 52,
#           ('number', 'NOUN'): 45,
#           ('Four', 'NUM'): 1,
#           ('five', 'NUM'): 29,
#           ('surviving', 'VERB'): 3,
#           ('asbestos-related', 'ADJ'): 3,
#           ('diseases', 'NOUN'): 7,
#           ('including', 'VERB'): 38,
#           ('recently', 'ADV'): 25,
#           ('diagnosed', 'VERB'): 1,
#           ('total', 'NOUN'): 9,
#           ('18', 'NUM'): 18,
#           ('malignant', 'ADJ'): 1,
#           ('mesothelioma', 'NOUN'): 1,
#           ('lung', 'NOUN'): 2,
#           ('asbestosis', 'NOUN'): 1,
#           ('far', 'ADV'): 28,
#           ('higher', 'ADJ'): 47,
#           ('*?*', 'X'): 45,
#           ('morbidity', 'NOUN'): 1,
#           ('rate', 'NOUN'): 41,
#           ('striking', 'ADJ'): 2,
#           ('finding', 'NOUN'): 4,
#           ('those', 'DET'): 55,
#           ('us', 'PRON'): 26,
#           ('*T*-5', 'X'): 5,
#           ('study', 'VERB'): 3,
#           ('West', 'NOUN'): 11,
#           ('Groton', 'NOUN'): 1,
#           ('Mass.', 'NOUN'): 8,
#           ('factory', 'NOUN'): 12,
#           ('appears', 'VERB'): 8,
#           ('be', 'VERB'): 356,
#           ('highest', 'ADJ'): 8,
#           ('Western', 'ADJ'): 6,
#           ('industrialized', 'VERB'): 2,
#           ('countries', 'NOUN'): 21,
#           ('he', 'PRON'): 230,
#           ('plant', 'NOUN'): 21,
#           ('which', 'DET'): 224,
#           ('owned', 'VERB'): 6,
#           ('*-4', 'X'): 34,
#           ('by', 'ADP'): 427,
#           ('Hollingsworth', 'NOUN'): 2,
#           ('&', 'CONJ'): 85,
#           ('Vose', 'NOUN'): 2,
#           ('Co.', 'NOUN'): 74,
#           ('under', 'ADP'): 60,
#           ('contract', 'NOUN'): 36,
#           ('*ICH*-2', 'X'): 34,
#           ('probably', 'ADV'): 14,
#           ('support', 'VERB'): 10,
#           ('*T*-6', 'X'): 2,
#           ('argue', 'VERB'): 6,
#           ('that', 'ADP'): 513,
#           ('U.S.', 'NOUN'): 220,
#           ('should', 'VERB'): 38,
#           ('regulate', 'VERB'): 2,
#           ('class', 'NOUN'): 8,
#           ('stringently', 'ADV'): 1,
#           ('common', 'ADJ'): 54,
#           ('kind', 'NOUN'): 12,
#           ('chrysotile', 'NOUN'): 2,
#           ('found', 'VERB'): 23,
#           ('most', 'ADJ'): 42,
#           ('other', 'ADJ'): 134,
#           ('buildings', 'NOUN'): 3,
#           ('one', 'NUM'): 121,
#           ('few', 'ADJ'): 33,
#           ('nations', 'NOUN'): 15,
#           ('*T*-7', 'X'): 2,
#           ('does', 'VERB'): 54,
#           ("n't", 'ADV'): 325,
#           ('standard', 'NOUN'): 2,
#           ('regulation', 'NOUN'): 3,
#           ('smooth', 'ADJ'): 1,
#           ('needle-like', 'ADJ'): 1,
#           ('fibers', 'NOUN'): 4,
#           ('such', 'ADJ'): 82,
#           ('classified', 'VERB'): 1,
#           ('*-5', 'X'): 11,
#           ('amphobiles', 'NOUN'): 1,
#           ('according', 'VERB'): 34,
#           ('Brooke', 'NOUN'): 1,
#           ('T.', 'NOUN'): 11,
#           ('Mossman', 'NOUN'): 2,
#           ('professor', 'NOUN'): 8,
#           ('pathlogy', 'NOUN'): 1,
#           ('Vermont', 'NOUN'): 1,
#           ('College', 'NOUN'): 6,
#           ('More', 'ADV'): 2,
#           ('curly', 'ADJ'): 1,
#           ('easily', 'ADV'): 6,
#           ('rejected', 'VERB'): 11,
#           ('body', 'NOUN'): 2,
#           ('explained', 'VERB'): 3,
#           ('In', 'ADP'): 195,
#           ('July', 'NOUN'): 8,
#           ('Environmental', 'NOUN'): 1,
#           ('Protection', 'NOUN'): 1,
#           ('Agency', 'NOUN'): 5,
#           ('imposed', 'VERB'): 3,
#           ('gradual', 'ADJ'): 1,
#           ('ban', 'NOUN'): 10,
#           ('virtually', 'ADV'): 6,
#           ('all', 'DET'): 100,
#           ('uses', 'NOUN'): 4,
#           ('By', 'ADP'): 11,
#           ('1997', 'NUM'): 1,
#           ('almost', 'ADV'): 22,
#           ('remaining', 'VERB'): 9,
#           ('cancer-causing', 'ADJ'): 1,
#           ('outlawed', 'VERB'): 1,
#           ('*-6', 'X'): 4,
#           ('About', 'ADP'): 6,
#           ('160', 'NUM'): 1,
#           ('*T*-8', 'X'): 2,
#           ('made', 'VERB'): 56,
#           ('*-7', 'X'): 4,
#           ('Areas', 'NOUN'): 1,
#           ('particularly', 'ADV'): 17,
#           ('dusty', 'ADJ'): 1,
#           ('where', 'ADV'): 34,
#           ('*-8', 'X'): 2,
#           ('Workers', 'NOUN'): 2,
#           ('dumped', 'VERB'): 4,
#           ('large', 'ADJ'): 29,
#           ('burlap', 'NOUN'): 1,
#           ('sacks', 'NOUN'): 1,
#           ('imported', 'VERB'): 4,
#           ('material', 'NOUN'): 10,
#           ('into', 'ADP'): 87,
#           ('huge', 'ADJ'): 14,
#           ('bin', 'NOUN'): 1,
#           ('poured', 'VERB'): 1,
#           ('in', 'PRT'): 15,
#           ('cotton', 'NOUN'): 1,
#           ('acetate', 'NOUN'): 1,
#           ('mechanically', 'ADV'): 1,
#           ('mixed', 'VERB'): 8,
#           ('dry', 'ADJ'): 4,
#           ('process', 'NOUN'): 13,
#           ('described', 'VERB'): 8,
#           ('clouds', 'NOUN'): 1,
#           ('blue', 'ADJ'): 5,
#           ('dust', 'NOUN'): 1,
#           ('hung', 'VERB'): 1,
#           ('over', 'ADP'): 72,
#           ('parts', 'NOUN'): 7,
#           ('though', 'ADP'): 25,
#           ('exhaust', 'NOUN'): 1,
#           ('fans', 'NOUN'): 2,
#           ('ventilated', 'VERB'): 1,
#           ('area', 'NOUN'): 9,
#           ("'s", 'VERB'): 103,
#           ('question', 'NOUN'): 12,
#           ('some', 'DET'): 122,
#           ('managers', 'NOUN'): 40,
#           ('contracted', 'VERB'): 2,
#           ('Darrell', 'NOUN'): 1,
#           ('Phillips', 'NOUN'): 2,
#           ('vice', 'NOUN'): 43,
#           ('president', 'NOUN'): 133,
#           ('human', 'ADJ'): 4,
#           ('resources', 'NOUN'): 5,
#           ('But', 'CONJ'): 157,
#           ('you', 'PRON'): 70,
#           ('recognize', 'VERB'): 3,
#           ('these', 'DET'): 55,
#           ('events', 'NOUN'): 3,
#           ('took', 'VERB'): 28,
#           ('place', 'NOUN'): 17,
#           ('35', 'NUM'): 7,
#           ('It', 'PRON'): 100,
#           ('bearing', 'NOUN'): 1,
#           ('work', 'NOUN'): 19,
#           ('force', 'NOUN'): 16,
#           ('Yields', 'NOUN'): 1,
#           ('money-market', 'ADJ'): 3,
#           ('mutual', 'ADJ'): 8,
#           ('funds', 'NOUN'): 67,
#           ('continued', 'VERB'): 14,
#           ('slide', 'VERB'): 1,
#           ('amid', 'ADP'): 4,
#           ('signs', 'NOUN'): 8,
#           ('portfolio', 'NOUN'): 9,
#           ('expect', 'VERB'): 8,
#           ('further', 'ADJ'): 11,
#           ('declines', 'NOUN'): 5,
#           ('interest', 'NOUN'): 53,
#           ('rates', 'NOUN'): 49,
#           ('average', 'ADJ'): 22,
#           ('seven-day', 'ADJ'): 3,
#           ('compound', 'NOUN'): 4,
#           ('yield', 'NOUN'): 20,
#           ('400', 'NUM'): 7,
#           ('taxable', 'ADJ'): 2,
#           ('tracked', 'VERB'): 1,
#           ('IBC', 'NOUN'): 1,
#           ('Money', 'NOUN'): 6,
#           ('Fund', 'NOUN'): 12,
#           ('Report', 'NOUN'): 8,
#           ('eased', 'VERB'): 3,
#           ('fraction', 'NOUN'): 1,
#           ('point', 'NOUN'): 26,
#           ('8.45', 'NUM'): 2,
#           ('%', 'NOUN'): 445,
#           ('8.47', 'NUM'): 2,
#           ('week', 'NOUN'): 55,
#           ('ended', 'VERB'): 24,
#           ('Tuesday', 'NOUN'): 46,
#           ('Compound', 'NOUN'): 1,
#           ('yields', 'NOUN'): 7,
#           ('assume', 'VERB'): 4,
#           ('reinvestment', 'NOUN'): 1,
#           ('dividends', 'NOUN'): 21,
#           ('current', 'ADJ'): 30,
#           ('continues', 'VERB'): 13,
#           ('Average', 'ADJ'): 4,
#           ('maturity', 'NOUN'): 3,
#           ("'", 'PRT'): 63,
#           ('investments', 'NOUN'): 17,
#           ('lengthened', 'VERB'): 1,
#           ('day', 'NOUN'): 23,
#           ('41', 'NUM'): 4,
#           ('days', 'NOUN'): 51,
#           ('longest', 'ADJ'): 1,
#           ('since', 'ADP'): 50,
#           ('August', 'NOUN'): 18,
#           ('Donoghue', 'NOUN'): 1,
#           ('Longer', 'ADJ'): 1,
#           ('maturities', 'NOUN'): 3,
#           ('thought', 'VERB'): 7,
#           ('indicate', 'VERB'): 3,
#           ('declining', 'VERB'): 4,
#           ('because', 'ADP'): 116,
#           ('they', 'PRON'): 210,
#           ('permit', 'VERB'): 3,
#           ('retain', 'VERB'): 3,
#           ('relatively', 'ADV'): 11,
#           ('longer', 'ADJ'): 4,
#           ('period', 'NOUN'): 25,
#           ('Shorter', 'ADJ'): 1,
#           ('considered', 'VERB'): 9,
#           ('*-9', 'X'): 2,
#           ('sign', 'NOUN'): 9,
#           ('rising', 'VERB'): 11,
#           ('can', 'VERB'): 93,
#           ('capture', 'VERB'): 4,
#           ('sooner', 'ADV'): 2,
#           ('open', 'ADJ'): 7,
#           ('only', 'ADV'): 68,
#           ('institutions', 'NOUN'): 18,
#           ('stronger', 'ADJ'): 5,
#           ('indicator', 'NOUN'): 4,
#           ('watch', 'VERB'): 7,
#           ('market', 'NOUN'): 176,
#           ('reached', 'VERB'): 17,
#           ('Nevertheless', 'ADV'): 2,
#           ('Brenda', 'NOUN'): 1,
#           ('Malizia', 'NOUN'): 1,
#           ('Negus', 'NOUN'): 1,
#           ('editor', 'NOUN'): 11,
#           ('may', 'VERB'): 70,
#           ('blip', 'VERB'): 2,
#           ('again', 'ADV'): 14,
#           ('down', 'PRT'): 14,
#           ('recent', 'ADJ'): 72,
#           ('rises', 'NOUN'): 1,
#           ('short-term', 'ADJ'): 14,
#           ('six-month', 'ADJ'): 6,
#           ('Treasury', 'NOUN'): 41,
#           ('bills', 'NOUN'): 19,
#           ('Monday', 'NOUN'): 12,
#           ('auction', 'NOUN'): 5,
#           ('example', 'NOUN'): 27,
#           ('rose', 'VERB'): 61,
#           ('8.04', 'NUM'): 2,
#           ('7.90', 'NUM'): 4,
#           ('Despite', 'ADP'): 11,
#           ('investors', 'NOUN'): 63,
#           ('continue', 'VERB'): 20,
#           ('pour', 'VERB'): 1,
#           ('cash', 'NOUN'): 43,
#           ('money', 'NOUN'): 53,
#           ('Assets', 'NOUN'): 1,
#           ('grew', 'VERB'): 4,
#           ('$', '.'): 718,
#           ('1.5', 'NUM'): 7,
#           ('*U*', 'X'): 744,
#           ('during', 'ADP'): 38,
#           ('352.7', 'NUM'): 1,
#           ('Typically', 'ADV'): 2,
#           ('money-fund', 'NOUN'): 1,
#           ('beat', 'VERB'): 6,
#           ('comparable', 'ADJ'): 3,
#           ('vary', 'VERB'): 2,
#           ('go', 'VERB'): 22,
#           ('after', 'ADP'): 77,
#           ('top', 'ADJ'): 10,
#           ('currently', 'ADV'): 22,
#           ('yielding', 'VERB'): 3,
#           ('well', 'ADV'): 46,
#           ('9', 'NUM'): 18,
#           ('Dreyfus', 'NOUN'): 1,
#           ('World-Wide', 'NOUN'): 1,
#           ('Dollar', 'NOUN'): 2,
#           ('top-yielding', 'ADJ'): 1,
#           ('fund', 'NOUN'): 11,
#           ('had', 'VERB'): 165,
#           ('9.37', 'NUM'): 1,
#           ('down', 'ADV'): 22,
#           ('9.45', 'NUM'): 1,
#           ('earlier', 'ADJ'): 34,
#           ('invests', 'VERB'): 1,
#           ('heavily', 'ADV'): 7,
#           ('dollar-denominated', 'ADJ'): 3,
#           ('securities', 'NOUN'): 33,
#           ('overseas', 'ADV'): 4,
#           ('waiving', 'VERB'): 1,
#           ('management', 'NOUN'): 22,
#           ('fees', 'NOUN'): 19,
#           ('*T*-9', 'X'): 2,
#           ('boosts', 'VERB'): 3,
#           ('simple', 'ADJ'): 4,
#           ('8.12', 'NUM'): 1,
#           ('8.14', 'NUM'): 1,
#           ('30-day', 'ADJ'): 8,
#           ('fell', 'VERB'): 32,
#           ('8.19', 'NUM'): 1,
#           ('8.22', 'NUM'): 1,
#           (';', '.'): 171,
#           ('slid', 'VERB'): 2,
#           ('8.53', 'NUM'): 1,
#           ('8.56', 'NUM'): 1,
#           ('J.P.', 'NOUN'): 1,
#           ('Bolduc', 'NOUN'): 1,
#           ('W.R.', 'NOUN'): 3,
#           ('Grace', 'NOUN'): 4,
#           ('*T*-10', 'X'): 2,
#           ('holds', 'VERB'): 4,
#           ('83.4', 'NUM'): 1,
#           ('energy-services', 'ADJ'): 1,
#           ('elected', 'VERB'): 6,
#           ('*-10', 'X'): 2,
#           ('He', 'PRON'): 73,
#           ('succeeds', 'VERB'): 2,
#           ('Terrence', 'NOUN'): 1,
#           ('D.', 'NOUN'): 15,
#           ('Daniels', 'NOUN'): 1,
#           ('formerly', 'ADV'): 3,
#           ('*T*-11', 'X'): 2,
#           ('resigned', 'VERB'): 5,
#           ('Energy', 'NOUN'): 6,
#           ('seven', 'NUM'): 9,
#           ('seats', 'NOUN'): 7,
#           ('Pacific', 'NOUN'): 10,
#           ('First', 'NOUN'): 35,
#           ('Financial', 'NOUN'): 14,
#           ('shareholders', 'NOUN'): 20,
#           ('approved', 'VERB'): 25,
#           ('acquisition', 'NOUN'): 15,
#           ('Royal', 'NOUN'): 1,
#           ('Trustco', 'NOUN'): 1,
#           ('Ltd.', 'NOUN'): 19,
#           ('Toronto', 'NOUN'): 5,
#           ('27', 'NUM'): 5,
#           ('share', 'NOUN'): 116,
#           ('or', 'CONJ'): 291,
#           ('212', 'NUM'): 1,
#           ('million', 'NUM'): 383,
#           ('thrift', 'NOUN'): 18,
#           ('holding', 'VERB'): 17,
#           ('expects', 'VERB'): 19,
#           ('obtain', 'VERB'): 3,
#           ('regulatory', 'ADJ'): 8,
#           ('approval', 'NOUN'): 10,
#           ('complete', 'VERB'): 6,
#           ('transaction', 'NOUN'): 20,
#           ('year-end', 'NOUN'): 2,
#           ('McDermott', 'NOUN'): 1,
#           ('International', 'NOUN'): 33,
#           ('Babcock', 'NOUN'): 1,
#           ('Wilcox', 'NOUN'): 1,
#           ('completed', 'VERB'): 15,
#           ('sale', 'NOUN'): 27,
#           ('Bailey', 'NOUN'): 3,
#           ('Controls', 'NOUN'): 2,
#           ('Operations', 'NOUN'): 2,
#           ('Finmeccanica', 'NOUN'): 2,
#           ('S.p', 'NOUN'): 1,
#           ('295', 'NUM'): 1,
#           ('Italian', 'ADJ'): 4,
#           ('state-owned', 'ADJ'): 2,
#           ('interests', 'NOUN'): 7,
#           ('mechanical', 'ADJ'): 4,
#           ('engineering', 'NOUN'): 8,
#           ('industry', 'NOUN'): 41,
#           ('based', 'VERB'): 31,
#           ('Wickliffe', 'NOUN'): 1,
#           ('Ohio', 'NOUN'): 9,
#           ('computerized', 'ADJ'): 1,
#           ('controls', 'NOUN'): 3,
#           ('systems', 'NOUN'): 6,
#           ('employs', 'VERB'): 3,
#           ('2,700', 'NUM'): 1,
#           ('people', 'NOUN'): 56,
#           ('annual', 'ADJ'): 17,
#           ('revenue', 'NOUN'): 11,
#           ('370', 'NUM'): 1,
#           ('federal', 'ADJ'): 51,
#           ('government', 'NOUN'): 83,
#           ('suspended', 'VERB'): 9,
#           ('sales', 'NOUN'): 59,
#           ('savings', 'NOUN'): 13,
#           ('bonds', 'NOUN'): 59,
#           ('Congress', 'NOUN'): 46,
#           ('lifted', 'VERB'): 2,
#           ('ceiling', 'NOUN'): 10,
#           ('debt', 'NOUN'): 46,
#           ('Until', 'ADP'): 5,
#           ('acts', 'VERB'): 2,
#           ('authority', 'NOUN'): 12,
#           ('issue', 'VERB'): 6,
#           ('obligations', 'NOUN'): 2,
#           ('borrowing', 'NOUN'): 3,
#           ('dropped', 'VERB'): 13,
#           ('midnight', 'NOUN'): 2,
#           ('2.80', 'NUM'): 1,
#           ('trillion', 'NUM'): 5,
#           ('2.87', 'NUM'): 2,
#           ('Legislation', 'NOUN'): 1,
#           ('lift', 'VERB'): 4,
#           ('ensnarled', 'VERB'): 1,
#           ('*-11', 'X'): 2,
#           ('fight', 'NOUN'): 3,
#           ('cutting', 'VERB'): 5,
#           ('capital-gains', 'ADJ'): 1,
#           ('taxes', 'NOUN'): 4,
#           ('House', 'NOUN'): 55,
#           ('voted', 'VERB'): 5,
#           ('raise', 'VERB'): 20,
#           ('3.1', 'NUM'): 5,
#           ('but', 'CONJ'): 150,
#           ('Senate', 'NOUN'): 18,
#           ('act', 'VERB'): 6,
#           ('until', 'ADP'): 31,
#           ('next', 'ADJ'): 58,
#           ('earliest', 'ADJ'): 1,
#           ('default', 'VERB'): 1,
#           ('if', 'ADP'): 80,
#           ('then', 'ADV'): 27,
#           ('Clark', 'NOUN'): 1,
#           ('J.', 'NOUN'): 15,
#           ('Vitulli', 'NOUN'): 2,
#           ('*-12', 'X'): 2,
#           ('senior', 'ADJ'): 18,
#           ('*RNR*-1', 'X'): 34,
#           ('general', 'ADJ'): 19,
#           ('manager', 'NOUN'): 27,
#           ('marketing', 'NOUN'): 14,
#           ('arm', 'NOUN'): 3,
#           ('Japanese', 'ADJ'): 80,
#           ('auto', 'NOUN'): 13,
#           ('maker', 'NOUN'): 28,
#           ('Mazda', 'NOUN'): 2,
#           ('Motor', 'NOUN'): 7,
#           ('Corp', 'NOUN'): 11,
#           ('position', 'NOUN'): 12,
#           ('oversee', 'VERB'): 1,
#           ('service', 'NOUN'): 24,
#           ('operations', 'NOUN'): 29,
#           ('Previously', 'ADV'): 4,
#           ('43', 'NUM'): 3,
#           ('Chrysler', 'NOUN'): 6,
#           ('division', 'NOUN'): 24,
#           ('been', 'VERB'): 150,
#           ('executive', 'NOUN'): 40,
#           ('20', 'NUM'): 25,
#           ('When', 'ADV'): 21,
#           ('time', 'NOUN'): 62,
#           ('their', 'PRON'): 181,
#           ('biannual', 'ADJ'): 1,
#           ('powwow', 'NOUN'): 1,
#           ('nation', 'NOUN'): 25,
#           ('manufacturing', 'VERB'): 8,
#           ('titans', 'NOUN'): 1,
#           ('typically', 'ADV'): 3,
#           ('jet', 'VERB'): 1,
#           ('off', 'PRT'): 27,
#           ('sunny', 'ADJ'): 1,
#           ('confines', 'NOUN'): 1,
#           ('resort', 'NOUN'): 2,
#           ('towns', 'NOUN'): 2,
#           ('like', 'ADP'): 44,
#           ('Boca', 'NOUN'): 3,
#           ('Raton', 'NOUN'): 2,
#           ('Hot', 'NOUN'): 1,
#           ('Springs', 'NOUN'): 3,
#           ('Not', 'ADV'): 7,
#           ('Association', 'NOUN'): 21,
#           ('Manufacturers', 'NOUN'): 3,
#           ('settled', 'VERB'): 5,
#           ('Hoosier', 'NOUN'): 1,
#           ('capital', 'NOUN'): 32,
#           ('Indianapolis', 'NOUN'): 4,
#           ('fall', 'NOUN'): 15,
#           ('meeting', 'NOUN'): 16,
#           ('And', 'CONJ'): 44,
#           ('city', 'NOUN'): 17,
#           ('decided', 'VERB'): 16,
#           ('treat', 'VERB'): 4,
#           ('guests', 'NOUN'): 3,
#           ('royalty', 'NOUN'): 1,
#           ('rock', 'NOUN'): 1,
#           ('stars', 'NOUN'): 2,
#           ('owners', 'NOUN'): 4,
#           ('idea', 'NOUN'): 11,
#           ('course', 'NOUN'): 11,
#           (':', '.'): 142,
#           ('prove', 'VERB'): 9,
#           ('125', 'NUM'): 4,
#           ('corporate', 'ADJ'): 25,
#           ('decision', 'NOUN'): 19,
#           ('makers', 'NOUN'): 12,
#           ('buckle', 'NOUN'): 1,
#           ('Rust', 'NOUN'): 1,
#           ('Belt', 'NOUN'): 3,
#           ('so', 'ADV'): 55,
#           ('rusty', 'ADJ'): 1,
#           ('good', 'ADJ'): 40,
#           ('expand', 'VERB'): 5,
#           ('On', 'ADP'): 17,
#           ('receiving', 'VERB'): 4,
#           ('end', 'NOUN'): 23,
#           ('message', 'NOUN'): 4,
#           ('officials', 'NOUN'): 47,
#           ('giants', 'NOUN'): 2,
#           ('Du', 'NOUN'): 2,
#           ('Pont', 'NOUN'): 2,
#           ('Maytag', 'NOUN'): 1,
#           ('along', 'ADP'): 6,
#           ('lesser', 'ADJ'): 1,
#           ('knowns', 'NOUN'): 1,
#           ('Trojan', 'NOUN'): 1,
#           ('Steel', 'NOUN'): 5,
#           ('Valley', 'NOUN'): 12,
#           ('Queen', 'NOUN'): 1,
#           ('Cheese', 'NOUN'): 1,
#           ('Factory', 'NOUN'): 4,
#           ('For', 'ADP'): 36,
#           ('starters', 'NOUN'): 1,
#           ('executives', 'NOUN'): 19,
#           ('joined', 'VERB'): 4,
#           ('Mayor', 'NOUN'): 2,
#           ('William', 'NOUN'): 23,
#           ('H.', 'NOUN'): 5,
#           ('Hudnut', 'NOUN'): 1,
#           ('III', 'NOUN'): 3,
#           ('evening', 'NOUN'): 4,
#           ('Symphony', 'NOUN'): 1,
#           ('Orchestra', 'NOUN'): 1,
#           ('guest', 'NOUN'): 1,
#           ('pianist-comedian', 'NOUN'): 1,
#           ('Victor', 'NOUN'): 2,
#           ('Borge', 'NOUN'): 1,
#           ('Champagne', 'NOUN'): 4,
#           ('dessert', 'NOUN'): 1,
#           ('followed', 'VERB'): 12,
#           ('morning', 'NOUN'): 4,
#           ('police', 'NOUN'): 5,
#           ('escort', 'NOUN'): 1,
#           ('busloads', 'NOUN'): 1,
#           ('wives', 'NOUN'): 1,
#           ('raced', 'VERB'): 1,
#           ('Speedway', 'NOUN'): 1,
#           ('unimpeded', 'ADJ'): 1,
#           ('traffic', 'NOUN'): 1,
#           ('red', 'ADJ'): 2,
#           ('lights', 'NOUN'): 2,
#           ('governor', 'NOUN'): 3,
#           ('could', 'VERB'): 120,
#           ('so', 'ADP'): 16,
#           ('lieutenant', 'NOUN'): 1,
#           ('welcomed', 'VERB'): 2,
#           ('special', 'ADJ'): 15,
#           ('buffet', 'NOUN'): 1,
#           ('breakfast', 'NOUN'): 1,
#           ('held', 'VERB'): 21,
#           ('museum', 'NOUN'): 2,
#           ('food', 'NOUN'): 16,
#           ('drinks', 'NOUN'): 1,
#           ('banned', 'VERB'): 3,
#           ('everyday', 'ADJ'): 1,
#           ('visitors', 'NOUN'): 2,
#           ('Then', 'ADV'): 7,
#           ('honor', 'NOUN'): 2,
#           ('speedway', 'NOUN'): 1,
#           ('hauled', 'VERB'): 1,
#           ('out', 'PRT'): 47,
#           ('four', 'NUM'): 20,
#           ('drivers', 'NOUN'): 3,
#           ('crews', 'NOUN'): 1,
#           ('official', 'ADJ'): 3,
#           ('500', 'NUM'): 38,
#           ('announcer', 'NOUN'): 5,
#           ('10-lap', 'ADJ'): 1,
#           ('exhibition', 'NOUN'): 2,
#           ('race', 'NOUN'): 3,
#           ('After', 'ADP'): 10,
#           ('Fortune', 'NOUN'): 1,
#           ('drooled', 'VERB'): 1,
#           ('schoolboys', 'NOUN'): 1,
#           ('cars', 'NOUN'): 19,
#           ('No', 'DET'): 10,
#           ('dummies', 'NOUN'): 1,
#           ('pointed', 'VERB'): 3,
#           ('still', 'ADV'): 36,
#           ('space', 'NOUN'): 9,
#           ('machines', 'NOUN'): 2,
#           ('another', 'DET'): 42,
#           ('sponsor', 'NOUN'): 2,
#           ('name', 'NOUN'): 7,
#           ('two', 'NUM'): 103,
#           ('Back', 'ADV'): 1,
#           ('downtown', 'NOUN'): 2,
#           ('execs', 'NOUN'): 1,
#           ('squeezed', 'VERB'): 2,
#           ('meetings', 'NOUN'): 6,
#           ('hotel', 'NOUN'): 3,
#           ('boarding', 'VERB'): 1,
#           ('buses', 'NOUN'): 3,
#           ('dinner', 'NOUN'): 2,
#           ('dancing', 'NOUN'): 1,
#           ('block', 'NOUN'): 3,
#           ('away', 'ADV'): 13,
#           ('Under', 'ADP'): 14,
#           ('moons', 'NOUN'): 1,
#           ('renovated', 'VERB'): 1,
#           ('Indiana', 'NOUN'): 5,
#           ('Roof', 'NOUN'): 1,
#           ('ballroom', 'NOUN'): 1,
#           ('nine', 'NUM'): 12,
#           ('hottest', 'ADJ'): 1,
#           ('chefs', 'NOUN'): 2,
#           ('town', 'NOUN'): 3,
#           ('fed', 'VERB'): 2,
#           ('them', 'PRON'): 70,
#           ('duckling', 'NOUN'): 1,
#           ('mousseline', 'NOUN'): 1,
#           ('lobster', 'NOUN'): 1,
#           ('consomme', 'NOUN'): 1,
#           ('veal', 'NOUN'): 1,
#           ('mignon', 'NOUN'): 1,
#           ('chocolate', 'ADJ'): 1,
#           ('terrine', 'NOUN'): 1,
#           ('raspberry', 'NOUN'): 1,
#           ('sauce', 'NOUN'): 1,
#           ('Knowing', 'VERB'): 1,
#           ('tasty', 'ADJ'): 1,
#           ('free', 'ADJ'): 13,
#           ('meal', 'NOUN'): 2,
#           ('when', 'ADV'): 77,
#           ('eat', 'VERB'): 1,
#           ('gave', 'VERB'): 10,
#           ('standing', 'ADJ'): 1,
#           ('ovation', 'NOUN'): 1,
#           ('More', 'ADJ'): 4,
#           ('CEOs', 'NOUN'): 2,
#           ('say', 'VERB'): 75,
#           ('red-carpet', 'ADJ'): 1,
#           ('treatment', 'NOUN'): 9,
#           ('tempts', 'VERB'): 1,
#           ('return', 'VERB'): 6,
#           ('heartland', 'NOUN'): 1,
#           ('future', 'ADJ'): 18,
#           ('looking', 'VERB'): 9,
#           ('forward', 'ADV'): 4,
#           ('winter', 'NOUN'): 1,
#           ('February', 'NOUN'): 3,
#           ('South', 'NOUN'): 39,
#           ('Korea', 'NOUN'): 19,
#           ('registered', 'VERB'): 6,
#           ('trade', 'NOUN'): 38,
#           ('deficit', 'NOUN'): 6,
#           ('101', 'NUM'): 2,
#           ('October', 'NOUN'): 61,
#           ('reflecting', 'VERB'): 4,
#           ('country', 'NOUN'): 46,
#           ('economic', 'ADJ'): 41,
#           ('sluggishness', 'NOUN'): 1,
#           ('figures', 'NOUN'): 12,
#           ('released', 'VERB'): 4,
#           ('Wednesday', 'NOUN'): 16,
#           ('Preliminary', 'ADJ'): 1,
#           ('tallies', 'NOUN'): 1,
#           ('Trade', 'NOUN'): 14,
#           ('Industry', 'NOUN'): 4,
#           ('Ministry', 'NOUN'): 10,
#           ('showed', 'VERB'): 13,
#           ('fifth', 'ADJ'): 7,
#           ('monthly', 'ADJ'): 7,
#           ('setback', 'NOUN'): 2,
#           ('casting', 'VERB'): 2,
#           ('cloud', 'NOUN'): 1,
#           ('export-oriented', 'ADJ'): 1,
#           ('economy', 'NOUN'): 26,
#           ('Exports', 'NOUN'): 1,
#           ('stood', 'VERB'): 5,
#           ('5.29', 'NUM'): 1,
#           ('mere', 'ADJ'): 2,
#           ('0.7', 'NUM'): 1,
#           ('increase', 'NOUN'): 20,
#           ('while', 'ADP'): 47,
#           ('imports', 'NOUN'): 12,
#           ('increased', 'VERB'): 23,
#           ('sharply', 'ADV'): 11,
#           ('5.39', 'NUM'): 1,
#           ('up', 'ADV'): 49,
#           ('last', 'ADJ'): 86,
#           ('boom', 'NOUN'): 2,
#           ('*T*-12', 'X'): 2,
#           ('began', 'VERB'): 32,
#           ('1986', 'NUM'): 10,
#           ('prolonged', 'VERB'): 2,
#           ('labor', 'NOUN'): 5,
#           ('disputes', 'NOUN'): 3,
#           ('conflicts', 'NOUN'): 2,
#           ('sluggish', 'ADJ'): 8,
#           ('exports', 'NOUN'): 11,
#           ('Government', 'NOUN'): 4,
#           ('would', 'VERB'): 209,
#           ('remain', 'VERB'): 12,
#           ('target', 'NOUN'): 8,
#           ('68', 'NUM'): 2,
#           ('gloomy', 'ADJ'): 1,
#           ('forecast', 'NOUN'): 4,
#           ('recorded', 'VERB'): 2,
#           ('surplus', 'NOUN'): 2,
#           ('71', 'NUM'): 3,
#           ('far', 'ADP'): 1,
#           ('January', 'NOUN'): 12,
#           ('accumulated', 'VERB'): 1,
#           ('4', 'NUM'): 15,
#           ('same', 'ADJ'): 37,
#           ('50.45', 'NUM'): 1,
#           ('Imports', 'NOUN'): 3,
#           ('50.38', 'NUM'): 1,
#           ('19', 'NUM'): 8,
#           ('Newsweek', 'NOUN'): 10,
#           ('trying', 'VERB'): 22,
#           ('keep', 'VERB'): 16,
#           ('pace', 'NOUN'): 6,
#           ('rival', 'ADJ'): 1,
#           ('Time', 'NOUN'): 8,
#           ('magazine', 'NOUN'): 23,
#           ('announced', 'VERB'): 17,
#           ('advertising', 'NOUN'): 10,
#           ('1990', 'NUM'): 43,
#           ('introduce', 'VERB'): 7,
#           ('incentive', 'NOUN'): 4,
#           ('plan', 'NOUN'): 45,
#           ('advertisers', 'NOUN'): 13,
#           ('ad', 'NOUN'): 28,
#           ('Washington', 'NOUN'): 23,
#           ('Post', 'NOUN'): 1,
#           ('second', 'ADJ'): 14,
#           ('offered', 'VERB'): 26,
#           ('Plans', 'NOUN'): 2,
#           ('*T*-13', 'X'): 2,
#           ('give', 'VERB'): 21,
#           ('discounts', 'NOUN'): 1,
#           ('maintaining', 'VERB'): 4,
#           ('increasing', 'VERB'): 18,
#           ('spending', 'NOUN'): 24,
#           ('become', 'VERB'): 23,
#           ('permanent', 'ADJ'): 2,
#           ('fixtures', 'NOUN'): 1,
#           ('news', 'NOUN'): 24,
#           ('weeklies', 'NOUN'): 2,
#           ('underscore', 'VERB'): 1,
#           ('fierce', 'ADJ'): 2,
#           ...})

# %%
wsj.index?

# %% [markdown]
# ### 关于词性的条件频率表

# %% [markdown]
# 给定词，按频率降序输出词性列表

# %%
cfdl = nltk.ConditionalFreqDist(wsj)#从配对链表中创建条件概率分布
cfdl['yield'].most_common()#此条件下给定样本的频率
# Out:
# [('VERB', 28), ('NOUN', 20)]

# %% [markdown]
# 给定词性，按频率降序输出词性列表

# %%
wsj = nltk.corpus.treebank.tagged_words()
cfd2 = nltk.ConditionalFreqDist((tag, word) for (word, tag) in wsj)
cfd2['VBN'].most_common()
# Out:
# [('been', 150),
#  ('expected', 52),
#  ('made', 33),
#  ('compared', 32),
#  ('based', 31),
#  ('used', 26),
#  ('priced', 26),
#  ('sold', 25),
#  ('named', 20),
#  ('designed', 20),
#  ('held', 18),
#  ('fined', 18),
#  ('taken', 16),
#  ('paid', 15),
#  ('traded', 15),
#  ('increased', 14),
#  ('said', 14),
#  ('filed', 13),
#  ('reached', 13),
#  ('called', 13),
#  ('scheduled', 13),
#  ('disclosed', 13),
#  ('reported', 12),
#  ('proposed', 12),
#  ('estimated', 12),
#  ('set', 12),
#  ('known', 12),
#  ('built', 11),
#  ('approved', 11),
#  ('given', 11),
#  ('acquired', 11),
#  ('found', 10),
#  ('offered', 10),
#  ('received', 10),
#  ('caused', 9),
#  ('considered', 9),
#  ('ordered', 9),
#  ('required', 9),
#  ('preferred', 9),
#  ('led', 9),
#  ('issued', 9),
#  ('fixed', 9),
#  ('listed', 9),
#  ('prepared', 9),
#  ('involved', 9),
#  ('aimed', 9),
#  ('needed', 9),
#  ('launched', 8),
#  ('produced', 8),
#  ('put', 8),
#  ('planned', 8),
#  ('seen', 8),
#  ('alleged', 8),
#  ('valued', 8),
#  ('barred', 8),
#  ('become', 7),
#  ('related', 7),
#  ('improved', 7),
#  ('changed', 7),
#  ('provided', 7),
#  ('come', 7),
#  ('got', 7),
#  ('allowed', 7),
#  ('mixed', 7),
#  ('suspended', 7),
#  ('owned', 6),
#  ('elected', 6),
#  ('worried', 6),
#  ('completed', 6),
#  ('combined', 6),
#  ('raised', 6),
#  ('left', 6),
#  ('placed', 6),
#  ('invested', 6),
#  ('fallen', 6),
#  ('failed', 6),
#  ('helped', 6),
#  ('run', 6),
#  ('opposed', 6),
#  ('quoted', 6),
#  ('continued', 6),
#  ('threatened', 6),
#  ('offset', 6),
#  ('shipped', 6),
#  ('eliminated', 6),
#  ('followed', 6),
#  ('sought', 6),
#  ('hurt', 6),
#  ('replaced', 5),
#  ('covered', 5),
#  ('boosted', 5),
#  ('registered', 5),
#  ('focused', 5),
#  ('closed', 5),
#  ('adjusted', 5),
#  ('written', 5),
#  ('had', 5),
#  ('managed', 5),
#  ('discovered', 5),
#  ('withdrawn', 5),
#  ('agreed', 5),
#  ('lost', 5),
#  ('formed', 5),
#  ('reduced', 5),
#  ('limited', 5),
#  ('done', 5),
#  ('delivered', 5),
#  ('studied', 4),
#  ('rejected', 4),
#  ('retired', 4),
#  ('located', 4),
#  ('believed', 4),
#  ('turned', 4),
#  ('awarded', 4),
#  ('spent', 4),
#  ('broken', 4),
#  ('opened', 4),
#  ('caught', 4),
#  ('refused', 4),
#  ('created', 4),
#  ('grown', 4),
#  ('gotten', 4),
#  ('chosen', 4),
#  ('indicated', 4),
#  ('associated', 4),
#  ('sent', 4),
#  ('pleased', 4),
#  ('forced', 4),
#  ('described', 4),
#  ('divided', 4),
#  ('financed', 4),
#  ('qualified', 4),
#  ('collected', 3),
#  ('determined', 3),
#  ('anticipated', 3),
#  ('incurred', 3),
#  ('brought', 3),
#  ('developed', 3),
#  ('denied', 3),
#  ('requested', 3),
#  ('announced', 3),
#  ('ranged', 3),
#  ('tied', 3),
#  ('jumped', 3),
#  ('cast', 3),
#  ('permitted', 3),
#  ('intended', 3),
#  ('coupled', 3),
#  ('played', 3),
#  ('carried', 3),
#  ('tested', 3),
#  ('revived', 3),
#  ('viewed', 3),
#  ('executed', 3),
#  ('convicted', 3),
#  ('blamed', 3),
#  ('accused', 3),
#  ('introduced', 3),
#  ('pursued', 3),
#  ('spurred', 3),
#  ('passed', 3),
#  ('gone', 3),
#  ('fired', 3),
#  ('posted', 3),
#  ('funded', 3),
#  ('charged', 3),
#  ('returned', 3),
#  ('signed', 3),
#  ('redeemed', 3),
#  ('ended', 3),
#  ('heard', 3),
#  ('employed', 3),
#  ('adopted', 3),
#  ('accepted', 3),
#  ('fueled', 3),
#  ('decided', 3),
#  ('contacted', 3),
#  ('kept', 3),
#  ('met', 3),
#  ('hit', 3),
#  ('soared', 3),
#  ('exercised', 3),
#  ('auctioned', 3),
#  ('disappointed', 3),
#  ('subordinated', 3),
#  ('integrated', 3),
#  ('performed', 3),
#  ('triggered', 3),
#  ('discussed', 3),
#  ('regulated', 3),
#  ('drawn', 3),
#  ('renewed', 3),
#  ('gained', 3),
#  ('owed', 3),
#  ('noted', 3),
#  ('stopped', 3),
#  ('regarded', 3),
#  ('included', 3),
#  ('rumored', 3),
#  ('respected', 3),
#  ('specified', 3),
#  ('abandoned', 3),
#  ('cut', 3),
#  ('marketed', 3),
#  ('tendered', 3),
#  ('exposed', 2),
#  ('industrialized', 2),
#  ('imported', 2),
#  ('thought', 2),
#  ('voted', 2),
#  ('banned', 2),
#  ('prolonged', 2),
#  ('moved', 2),
#  ('applied', 2),
#  ('trained', 2),
#  ('instituted', 2),
#  ('removed', 2),
#  ('concerned', 2),
#  ('forgiven', 2),
#  ('assembled', 2),
#  ('maintained', 2),
#  ('linked', 2),
#  ('advertised', 2),
#  ('skyrocketed', 2),
#  ('surged', 2),
#  ('targeted', 2),
#  ('repaid', 2),
#  ('crippled', 2),
#  ('settled', 2),
#  ('manufactured', 2),
#  ('confirmed', 2),
#  ('operated', 2),
#  ('romanticized', 2),
#  ('murdered', 2),
#  ('presented', 2),
#  ('worked', 2),
#  ('prompted', 2),
#  ('Stung', 2),
#  ('attracted', 2),
#  ('dumped', 2),
#  ('released', 2),
#  ('tried', 2),
#  ('dismissed', 2),
#  ('interviewed', 2),
#  ('referred', 2),
#  ('matched', 2),
#  ('measured', 2),
#  ('retained', 2),
#  ('chaired', 2),
#  ('obtained', 2),
#  ('relegated', 2),
#  ('compiled', 2),
#  ('Guaranteed', 2),
#  ('positioned', 2),
#  ('locked', 2),
#  ('Estimated', 2),
#  ('Founded', 2),
#  ('printed', 2),
#  ('handled', 2),
#  ('damaged', 2),
#  ('pressed', 2),
#  ('allocated', 2),
#  ('mired', 2),
#  ('installed', 2),
#  ('perceived', 2),
#  ('spread', 2),
#  ('moderated', 2),
#  ('frozen', 2),
#  ('surprised', 2),
#  ('cited', 2),
#  ('purchased', 2),
#  ('publicized', 2),
#  ('identified', 2),
#  ('expressed', 2),
#  ('attached', 2),
#  ('rung', 2),
#  ('started', 2),
#  ('absorbed', 2),
#  ('entered', 2),
#  ('founded', 2),
#  ('desired', 2),
#  ('risen', 2),
#  ('sustained', 2),
#  ('loaded', 2),
#  ('expelled', 2),
#  ('engaged', 2),
#  ('pegged', 2),
#  ('backed', 2),
#  ('enacted', 2),
#  ('faced', 2),
#  ('committed', 2),
#  ('confined', 2),
#  ('upset', 2),
#  ('connected', 2),
#  ('organized', 2),
#  ('diminished', 2),
#  ('added', 2),
#  ('answered', 2),
#  ('oriented', 2),
#  ('dominated', 2),
#  ('pushed', 2),
#  ('Posted', 2),
#  ('supported', 2),
#  ('contained', 2),
#  ('entrusted', 2),
#  ('secured', 2),
#  ('begun', 2),
#  ('labeled', 2),
#  ('beaten', 2),
#  ('cooled', 2),
#  ('discontinued', 2),
#  ('lowered', 2),
#  ('warned', 2),
#  ('selected', 2),
#  ('bolstered', 2),
#  ('attributed', 2),
#  ('restructured', 2),
#  ('bought', 2),
#  ('split', 2),
#  ('diluted', 2),
#  ('subdued', 2),
#  ('liquidated', 2),
#  ('capitalized', 2),
#  ('told', 2),
#  ('specialized', 2),
#  ('died', 1),
#  ('diagnosed', 1),
#  ('classified', 1),
#  ('outlawed', 1),
#  ('tracked', 1),
#  ('lifted', 1),
#  ('ensnarled', 1),
#  ('renovated', 1),
#  ('recorded', 1),
#  ('accumulated', 1),
#  ('guaranteed', 1),
#  ('cluttered', 1),
#  ('expedited', 1),
#  ('disputed', 1),
#  ('refunded', 1),
#  ('scrapped', 1),
#  ('existed', 1),
#  ('Regarded', 1),
#  ('vowed', 1),
#  ('deemed', 1),
#  ('complained', 1),
#  ('accelerated', 1),
#  ('solved', 1),
#  ('achieved', 1),
#  ('assisted', 1),
#  ('incorporated', 1),
#  ('capped', 1),
#  ('kicked', 1),
#  ('scrambled', 1),
#  ('outpaced', 1),
#  ('burned', 1),
#  ('clobbered', 1),
#  ('climbed', 1),
#  ('alarmed', 1),
#  ('fattened', 1),
#  ('lent', 1),
#  ('amended', 1),
#  ('watched', 1),
#  ('rooted', 1),
#  ('welcomed', 1),
#  ('rationed', 1),
#  ('assigned', 1),
#  ('designated', 1),
#  ('surveyed', 1),
#  ('strapped', 1),
#  ('twinned', 1),
#  ('painted', 1),
#  ('accrued', 1),
#  ('swapped', 1),
#  ('laid', 1),
#  ('obsessed', 1),
#  ('Filmed', 1),
#  ('populated', 1),
#  ('condemned', 1),
#  ('chopped', 1),
#  ('speculated', 1),
#  ('scattered', 1),
#  ('superimposed', 1),
#  ('nurtured', 1),
#  ('interrogated', 1),
#  ('rusted', 1),
#  ('responded', 1),
#  ('cleaned', 1),
#  ('asked', 1),
#  ('knitted', 1),
#  ('tripled', 1),
#  ('Confronted', 1),
#  ('prosecuted', 1),
#  ('treated', 1),
#  ('enhanced', 1),
#  ('inflated', 1),
#  ('surfaced', 1),
#  ('educated', 1),
#  ('faded', 1),
#  ('stabbed', 1),
#  ('learned', 1),
#  ('crowded', 1),
#  ('overused', 1),
#  ('expunged', 1),
#  ('wanted', 1),
#  ('replicated', 1),
#  ('embroiled', 1),
#  ('hampered', 1),
#  ('assured', 1),
#  ('judged', 1),
#  ('polarized', 1),
#  ('Rekindled', 1),
#  ('protected', 1),
#  ('argued', 1),
#  ('prohibited', 1),
#  ('initiated', 1),
#  ('mailed', 1),
#  ('UPHELD', 1),
#  ('sparked', 1),
#  ('killed', 1),
#  ('appointed', 1),
#  ('exhibited', 1),
#  ('empowered', 1),
#  ('served', 1),
#  ('Related', 1),
#  ('buoyed', 1),
#  ('convinced', 1),
#  ('mollified', 1),
#  ('rolled', 1),
#  ('flooded', 1),
#  ('alienated', 1),
#  ('chastised', 1),
#  ('portrayed', 1),
#  ('relied', 1),
#  ('recycled', 1),
#  ('Asked', 1),
#  ('scared', 1),
#  ('serviced', 1),
#  ('Developed', 1),
#  ('converted', 1),
#  ('equipped', 1),
#  ('classed', 1),
#  ('depressed', 1),
#  ('enclosed', 1),
#  ('dropped', 1),
#  ('rarefied', 1),
#  ('zoomed', 1),
#  ('commanded', 1),
#  ('exhausted', 1),
#  ('talked', 1),
#  ('excited', 1),
#  ('overpriced', 1),
#  ('stated', 1),
#  ('shown', 1),
#  ('declared', 1),
#  ('postponed', 1),
#  ('rescheduled', 1),
#  ('clamped', 1),
#  ('collapsed', 1),
#  ('interested', 1),
#  ('escalated', 1),
#  ('stoked', 1),
#  ('clarified', 1),
#  ('crossed', 1),
#  ('milked', 1),
#  ('assumed', 1),
#  ('competed', 1),
#  ('borrowed', 1),
#  ('squeezed', 1),
#  ('switched', 1),
#  ('cultivated', 1),
#  ('tailored', 1),
#  ('troubled', 1),
#  ('synchronized', 1),
#  ('muffled', 1),
#  ('mounted', 1),
#  ('filled', 1),
#  ('fed', 1),
#  ('remarked', 1),
#  ('observed', 1),
#  ('dressed', 1),
#  ('decorated', 1),
#  ('unsettled', 1),
#  ('Put', 1),
#  ('tanked', 1),
#  ('invented', 1),
#  ('infringed', 1),
#  ('hired', 1),
#  ('afflicted', 1),
#  ('deteriorated', 1),
#  ('codified', 1),
#  ('discarded', 1),
#  ('pointed', 1),
#  ('defined', 1),
#  ('represented', 1),
#  ('consented', 1),
#  ('Reached', 1),
#  ('rectified', 1),
#  ('blocked', 1),
#  ('forgotten', 1),
#  ('tightened', 1),
#  ('reaped', 1),
#  ('touted', 1),
#  ('negotiated', 1),
#  ('Given', 1),
#  ('impressed', 1),
#  ('engineered', 1),
#  ('diversified', 1),
#  ('expanded', 1),
#  ('provoked', 1),
#  ('stripped', 1),
#  ('reallocated', 1),
#  ('instructed', 1),
#  ('drafted', 1),
#  ('repaired', 1),
#  ('altered', 1),
#  ('corrected', 1),
#  ('promised', 1),
#  ('proved', 1),
#  ('understood', 1),
#  ('composed', 1),
#  ('robbed', 1),
#  ('deprived', 1),
#  ('impaired', 1),
#  ('advised', 1),
#  ('mentioned', 1),
#  ('contributed', 1),
#  ('OFFERED', 1),
#  ('Annualized', 1),
#  ('clashed', 1),
#  ('enjoyed', 1),
#  ('recruited', 1),
#  ('Provided', 1),
#  ('predicated', 1),
#  ('endorsed', 1),
#  ('construed', 1),
#  ('read', 1),
#  ('nominated', 1),
#  ('wasted', 1),
#  ('favored', 1),
#  ('disapproved', 1),
#  ('ratified', 1),
#  ('characterized', 1),
#  ('won', 1),
#  ('mortgaged', 1),
#  ('reclaimed', 1),
#  ('parched', 1),
#  ('cushioned', 1),
#  ('shut', 1),
#  ('attempted', 1),
#  ('torn', 1),
#  ('staid', 1),
#  ('flirted', 1),
#  ('stepped', 1),
#  ('headlined', 1),
#  ('beleaguered', 1),
#  ('plunged', 1),
#  ('missed', 1),
#  ('preapproved', 1),
#  ('upheld', 1),
#  ('accounted', 1),
#  ('vested', 1),
#  ('shaken', 1),
#  ('heated', 1),
#  ('exacerbated', 1),
#  ('wedded', 1),
#  ('headed', 1),
#  ('curbed', 1),
#  ('entrenched', 1),
#  ('stacked', 1),
#  ('frightened', 1),
#  ('automated', 1),
#  ('earned', 1),
#  ('spooked', 1),
#  ('transformed', 1),
#  ('orchestrated', 1),
#  ('gored', 1),
#  ('proven', 1),
#  ('minted', 1),
#  ('practiced', 1),
#  ('implemented', 1),
#  ('feared', 1),
#  ('Left', 1),
#  ('appropriated', 1),
#  ('noticed', 1),
#  ('finished', 1),
#  ('documented', 1),
#  ('colored', 1),
#  ('Funded', 1),
#  ('Concerned', 1),
#  ('echoed', 1),
#  ('halted', 1),
#  ('recouped', 1),
#  ('hunted', 1),
#  ('overcome', 1),
#  ('terminated', 1),
#  ('Rated', 1),
#  ('insured', 1),
#  ('rated', 1),
#  ('looked', 1),
#  ('justified', 1),
#  ('structured', 1),
#  ('generated', 1),
#  ('overstated', 1),
#  ('midsized', 1),
#  ('assessed', 1),
#  ('chilled', 1),
#  ('hidden', 1),
#  ('inserted', 1),
#  ('harmed', 1),
#  ('stressed', 1),
#  ('directed', 1),
#  ('stimulated', 1),
#  ('overdone', 1),
#  ('calculated', 1),
#  ('Named', 1),
#  ('revised', 1),
#  ('conducted', 1),
#  ('snapped', 1),
#  ('polled', 1),
#  ('topped', 1),
#  ('outdistanced', 1),
#  ('relaunched', 1),
#  ('repriced', 1),
#  ('concluded', 1),
#  ('hailed', 1),
#  ('despised', 1),
#  ('heightened', 1),
#  ('Used', 1),
#  ('nullified', 1),
#  ('puzzled', 1),
#  ('notified', 1),
#  ('merged', 1),
#  ('delisted', 1),
#  ('meant', 1),
#  ('own', 1),
#  ('singled', 1),
#  ('granted', 1),
#  ('felt', 1),
#  ('confused', 1),
#  ('complicated', 1),
#  ('muted', 1),
#  ('Continued', 1),
#  ('magnified', 1),
#  ('reimbursed', 1),
#  ('controlled', 1),
#  ('distributed', 1),
#  ('experienced', 1),
#  ('customized', 1),
#  ('extended', 1),
#  ('sweetened', 1),
#  ('derived', 1),
#  ('averted', 1),
#  ('slated', 1),
#  ('examined', 1),
#  ('reorganized', 1),
#  ('plagued', 1),
#  ('imposed', 1),
#  ('armed', 1),
#  ('rigged', 1),
#  ('subpoenaed', 1),
#  ('planted', 1),
#  ('centralized', 1),
#  ('resulted', 1),
#  ('forecast', 1),
#  ('fizzled', 1),
#  ('edged', 1),
#  ('battered', 1),
#  ('floated', 1),
#  ('spun', 1),
#  ('licensed', 1),
#  ('trimmed', 1),
#  ('detailed', 1),
#  ('born', 1),
#  ('fashioned', 1),
#  ('bribed', 1),
#  ('arrested', 1),
#  ('Absorbed', 1),
#  ('finalized', 1),
#  ('dashed', 1),
#  ('omitted', 1),
#  ('harvested', 1),
#  ('slowed', 1),
#  ('depleted', 1),
#  ('obligated', 1),
#  ('compressed', 1),
#  ('delayed', 1),
#  ('influenced', 1),
#  ('reflected', 1),
#  ('advanced', 1),
#  ('coated', 1),
#  ('shared', 1)]

# %% [markdown]
# 输出这个词的前四个单词
# [2:4]就是2,3（前含后不含）

# %%
idx1 = wsj.index(('kicked', 'VBD'))
wsj[idx1-4:idx1+1]#idx1+1是它后面一个，但后面一个是不含的
# Out:
# [('While', 'IN'),
#  ('program', 'NN'),
#  ('trades', 'NNS'),
#  ('swiftly', 'RB'),
#  ('kicked', 'VBD')]

# %% [markdown]
# ## 未简化的标记
#
# 名词NN的变种：含有$的名词所有格,含有S的复数名词，含有P的专有名词
# 后缀修饰符：-NC表示引用，-HL表示标题中的词，-TL表示标题

# %% [markdown]
# 找出所有以NN开头的tag，对于每一种tag打出最常用的五个词

# %%
def findtags(tag_prefix, tagged_text):
    cfd = nltk.ConditionalFreqDist((tag, word) for (word,tag) in tagged_text 
                                   if tag.startswith(tag_prefix))
    return {tag:cfd[tag].most_common(5) for tag in cfd.conditions()}

# %%
tagdict = findtags('NN',nltk.corpus.brown.tagged_words(categories='news'))
for tag in sorted(tagdict):
    print(tag,tagdict[tag])
# Out:
# NN [('year', 137), ('time', 97), ('state', 88), ('week', 85), ('man', 72)]
# NN$ [("year's", 13), ("world's", 8), ("state's", 7), ("nation's", 6), ("city's", 6)]
# NN$-HL [("Golf's", 1), ("Navy's", 1)]
# NN$-TL [("President's", 11), ("Administration's", 3), ("Army's", 3), ("League's", 3), ("University's", 3)]
# NN-HL [('sp.', 2), ('problem', 2), ('Question', 2), ('cut', 2), ('party', 2)]
# NN-NC [('ova', 1), ('eva', 1), ('aya', 1)]
# NN-TL [('President', 88), ('House', 68), ('State', 59), ('University', 42), ('City', 41)]
# NN-TL-HL [('Fort', 2), ('Mayor', 1), ('Commissioner', 1), ('City', 1), ('Oak', 1)]
# NNS [('years', 101), ('members', 69), ('people', 52), ('sales', 51), ('men', 46)]
# NNS$ [("children's", 7), ("women's", 5), ("men's", 3), ("janitors'", 3), ("taxpayers'", 2)]
# NNS$-HL [("Dealers'", 1), ("Idols'", 1)]
# NNS$-TL [("Women's", 4), ("States'", 3), ("Giants'", 2), ("Princes'", 1), ("Bombers'", 1)]
# NNS-HL [('Wards', 1), ('deputies', 1), ('bonds', 1), ('aspects', 1), ('Decisions', 1)]
# NNS-TL [('States', 38), ('Nations', 11), ('Masters', 10), ('Communists', 9), ('Rules', 9)]
# NNS-TL-HL [('Nations', 1)]

# %%
tagdict
# Out:
# {'NN': [('year', 137), ('time', 97), ('state', 88), ('week', 85), ('man', 72)],
#  'NN$': [("year's", 13),
#   ("world's", 8),
#   ("state's", 7),
#   ("nation's", 6),
#   ("city's", 6)],
#  'NN$-HL': [("Golf's", 1), ("Navy's", 1)],
#  'NN$-TL': [("President's", 11),
#   ("Administration's", 3),
#   ("Army's", 3),
#   ("League's", 3),
#   ("University's", 3)],
#  'NN-HL': [('sp.', 2),
#   ('problem', 2),
#   ('Question', 2),
#   ('cut', 2),
#   ('party', 2)],
#  'NN-NC': [('ova', 1), ('eva', 1), ('aya', 1)],
#  'NN-TL': [('President', 88),
#   ('House', 68),
#   ('State', 59),
#   ('University', 42),
#   ('City', 41)],
#  'NN-TL-HL': [('Fort', 2),
#   ('Mayor', 1),
#   ('Commissioner', 1),
#   ('City', 1),
#   ('Oak', 1)],
#  'NNS': [('years', 101),
#   ('members', 69),
#   ('people', 52),
#   ('sales', 51),
#   ('men', 46)],
#  'NNS$': [("children's", 7),
#   ("women's", 5),
#   ("men's", 3),
#   ("janitors'", 3),
#   ("taxpayers'", 2)],
#  'NNS$-HL': [("Dealers'", 1), ("Idols'", 1)],
#  'NNS$-TL': [("Women's", 4),
#   ("States'", 3),
#   ("Giants'", 2),
#   ("Princes'", 1),
#   ("Bombers'", 1)],
#  'NNS-HL': [('Wards', 1),
#   ('deputies', 1),
#   ('bonds', 1),
#   ('aspects', 1),
#   ('Decisions', 1)],
#  'NNS-TL': [('States', 38),
#   ('Nations', 11),
#   ('Masters', 10),
#   ('Communists', 9),
#   ('Rules', 9)],
#  'NNS-TL-HL': [('Nations', 1)]}

# %% [markdown]
# ### 查找标记的解释

# %%
nltk.help.upenn_tagset('JJ')
# Out:
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...

# %% [markdown]
# ### 查看跟在often 后面的词语

# %%
brown_learned_text = brown.words(categories='learned')
sorted(set(b for (a, b) in nltk.bigrams(brown_learned_text) if a == 'often'))
